# %%
import tensorflow as tf
import os
import sys

import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

import os
import sys
import copy
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize

from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D, Dense, Flatten
from tensorflow.keras.layers import concatenate, UpSampling2D

from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dropout, Lambda
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from sklearn.model_selection import train_test_split
import tensorflow.keras.backend as K
from tensorflow.keras.metrics import MeanIoU
import math
import cv2


from PIL import Image

# %%
# !chmod 775 /home/ragou/repo/github/mask/* -R

# %%
mrcnnpath = "/home/ragou/repo/github/mask/Mask_RCNN"
sys.path.append(mrcnnpath)

# %%
from mrcnn.model import MaskRCNN
from mrcnn.utils import Dataset
from mrcnn.config import Config

# %% [markdown]
# # 1 image = 1 PU

# %% [markdown]
# CONVERSION :
#
# # Position 67 pour une protéine ) 130 rés
#
# 130 --> 67
#
# 256 --> x
#
# x_scaled = 67 * 256/130 = 131
#
# x_scaled = pos * (SIZE/shape)
#
#
#
# # Reverse
#
# 256 --> 131
# 130 --> x
#
# x_true = 130 * (131/256)
#
# x_true = pos * (shape / SIZE)

# %%
 # class that defines and loads the kangaroo dataset
class PUDataset(Dataset):
    # load the dataset definitions
    def load_dataset(self, images_dir, prot_name):
        self.IMG_SIZE = 256
        # define one class
        self.add_class("dataset", 1, "PU")
        # define data locations
        # find all images
        for image_id,prot in enumerate(prot_name):
            prot = prot[0]
            img_path = images_dir + prot + f"/PDBs_Clean/{prot}.pdb{prot[-1]}" + "/file_proba_contact.mat"
            annot_path = images_dir + prot + f"/PDBs_Clean/{prot}.pdb{prot[-1]}" "/Peeling/Peeling.log"
            self.add_image('dataset', image_id=image_id, path=img_path, annot = annot_path)

    def log_to_res(self, logfile):
        all_coords = []
        with open(logfile) as filin:
            for line in filin:
                if not line.startswith("#"):
                    clean_coord = line.strip().split()[5:]
                    xy = [[int(clean_coord[x]),int(clean_coord[x+1])] for x in range(0,len(clean_coord)-1,2)]
                    all_coords.append(xy)
        return all_coords[-1]
    
    
    def get_PU(self, image_id):
        info = self.image_info[image_id]
        path = info['annot']
        PU = self.log_to_res(path)
        PU_list = []
        labels = []
        shape_image = sorted(PU)[-1][-1]
        for couple in PU:
            PU_list = []
            for res in couple:
                PU_list.append(int(res * self.IMG_SIZE /shape_image ))
            labels.append(PU_list)
        return labels
        
        
        
    def load_image(self, image_id):
        info = self.image_info[image_id]
        path = info['path']
        # print(path, flush=True)
        image = np.loadtxt(path,encoding='utf-8') * 255
        image = cv2.cvtColor(np.array(image).astype(np.uint8), cv2.COLOR_RGB2BGR)
        image = resize(image, (self.IMG_SIZE, self.IMG_SIZE), mode='constant', preserve_range=True).astype(np.uint8)
        return image
    
    # load the masks for an image
    def load_mask(self, image_id):
        # get details of image
        info = self.image_info[image_id]
        path = info['annot']
        # load XML
        PU_list = self.get_PU(image_id)
        # create one array for all masks, each on a different channel
        masks = np.zeros([self.IMG_SIZE, self.IMG_SIZE, len(PU_list)], dtype='uint8')
        # create masks
        class_ids = list()
        for i in range(len(PU_list)):
            box = PU_list[i]
            x, y = box[0], box[1]
            masks[x:y, x:y, i] = 1
            class_ids.append(1)
        return masks, np.asarray(class_ids, dtype='int32')
    

    # load an image reference
    def image_reference(self, image_id):
        info = self.image_info[image_id]
        return info['path']

# %%
# define a configuration for the model
class PUConfig(Config):
    # define the name of the configuration
    NAME = "SWORD_PU_cfg"
    # number of classes (background + PU)
    NUM_CLASSES = 1 + 1
    # number of training steps per epoch
    STEPS_PER_EPOCH = 131
    # # MAX_GT_INSTANCES = 50
    # # POST_NMS_ROIS_INFERENCE = 500
    # # POST_NMS_ROIS_TRAINING = 1000
    RPN_TRAIN_ANCHORS_PER_IMAGE = 256
    TRAIN_ROIS_PER_IMAGE = 200
    # NUMBER OF GPUs to use. When using only a CPU, this needs to be set to 1.
    GPU_COUNT = 1


    IMAGES_PER_GPU = 1

    USE_MINI_MASK = True
    MINI_MASK_SHAPE = (16, 16)  # (height, width) of the mini-mask
    BACKBONE = "resnet50"

    IMAGE_RESIZE_MODE = "square"
    IMAGE_MIN_DIM = IMAGE_MAX_DIM = 256

    # IMAGE_MIN_SCALE = 0
 
    IMAGE_CHANNEL_COUNT = 3
    LEARNING_RATE = 0.0001

# %%
images_dir = "../data/data_sword/"
prot_name = next(os.walk(images_dir))[1]

# %%
prot_name_dtf = pd.DataFrame(prot_name)
prot_train = prot_name_dtf.sample(frac= 0.5, random_state = 42)
prot_test = prot_name_dtf[~prot_name_dtf.isin(prot_train)].dropna()

# %%
train_set = PUDataset()
train_set.load_dataset(images_dir, prot_train.values.tolist())
train_set.prepare()

# %%
test_set = PUDataset()
test_set.load_dataset(images_dir, prot_test.values.tolist())
test_set.prepare()

# %%
plt.imshow(train_set.load_image(3))

# %%
plt.imshow(train_set.load_image(3))

# %%
train_set.image_info
# Out:
# [{'id': 0,
#   'source': 'dataset',
#   'path': '../data/data_sword/4EBBA/PDBs_Clean/4EBBA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/4EBBA/PDBs_Clean/4EBBA.pdbA/Peeling/Peeling.log'},
#  {'id': 1,
#   'source': 'dataset',
#   'path': '../data/data_sword/3TG7A/PDBs_Clean/3TG7A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3TG7A/PDBs_Clean/3TG7A.pdbA/Peeling/Peeling.log'},
#  {'id': 2,
#   'source': 'dataset',
#   'path': '../data/data_sword/1LVFA/PDBs_Clean/1LVFA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1LVFA/PDBs_Clean/1LVFA.pdbA/Peeling/Peeling.log'},
#  {'id': 3,
#   'source': 'dataset',
#   'path': '../data/data_sword/1VPMA/PDBs_Clean/1VPMA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1VPMA/PDBs_Clean/1VPMA.pdbA/Peeling/Peeling.log'},
#  {'id': 4,
#   'source': 'dataset',
#   'path': '../data/data_sword/2A1RA/PDBs_Clean/2A1RA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2A1RA/PDBs_Clean/2A1RA.pdbA/Peeling/Peeling.log'},
#  {'id': 5,
#   'source': 'dataset',
#   'path': '../data/data_sword/1ZMDA/PDBs_Clean/1ZMDA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1ZMDA/PDBs_Clean/1ZMDA.pdbA/Peeling/Peeling.log'},
#  {'id': 6,
#   'source': 'dataset',
#   'path': '../data/data_sword/1HE1A/PDBs_Clean/1HE1A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1HE1A/PDBs_Clean/1HE1A.pdbA/Peeling/Peeling.log'},
#  {'id': 7,
#   'source': 'dataset',
#   'path': '../data/data_sword/3MKOA/PDBs_Clean/3MKOA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3MKOA/PDBs_Clean/3MKOA.pdbA/Peeling/Peeling.log'},
#  {'id': 8,
#   'source': 'dataset',
#   'path': '../data/data_sword/2P9MA/PDBs_Clean/2P9MA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2P9MA/PDBs_Clean/2P9MA.pdbA/Peeling/Peeling.log'},
#  {'id': 9,
#   'source': 'dataset',
#   'path': '../data/data_sword/1WKVA/PDBs_Clean/1WKVA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1WKVA/PDBs_Clean/1WKVA.pdbA/Peeling/Peeling.log'},
#  {'id': 10,
#   'source': 'dataset',
#   'path': '../data/data_sword/3AXGA/PDBs_Clean/3AXGA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3AXGA/PDBs_Clean/3AXGA.pdbA/Peeling/Peeling.log'},
#  {'id': 11,
#   'source': 'dataset',
#   'path': '../data/data_sword/4EQ6B/PDBs_Clean/4EQ6B.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/4EQ6B/PDBs_Clean/4EQ6B.pdbB/Peeling/Peeling.log'},
#  {'id': 12,
#   'source': 'dataset',
#   'path': '../data/data_sword/2HUEB/PDBs_Clean/2HUEB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/2HUEB/PDBs_Clean/2HUEB.pdbB/Peeling/Peeling.log'},
#  {'id': 13,
#   'source': 'dataset',
#   'path': '../data/data_sword/1VR9A/PDBs_Clean/1VR9A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1VR9A/PDBs_Clean/1VR9A.pdbA/Peeling/Peeling.log'},
#  {'id': 14,
#   'source': 'dataset',
#   'path': '../data/data_sword/2YFAA/PDBs_Clean/2YFAA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2YFAA/PDBs_Clean/2YFAA.pdbA/Peeling/Peeling.log'},
#  {'id': 15,
#   'source': 'dataset',
#   'path': '../data/data_sword/1Q1HA/PDBs_Clean/1Q1HA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1Q1HA/PDBs_Clean/1Q1HA.pdbA/Peeling/Peeling.log'},
#  {'id': 16,
#   'source': 'dataset',
#   'path': '../data/data_sword/2PGWA/PDBs_Clean/2PGWA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2PGWA/PDBs_Clean/2PGWA.pdbA/Peeling/Peeling.log'},
#  {'id': 17,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BV2A/PDBs_Clean/2BV2A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BV2A/PDBs_Clean/2BV2A.pdbA/Peeling/Peeling.log'},
#  {'id': 18,
#   'source': 'dataset',
#   'path': '../data/data_sword/2OXOA/PDBs_Clean/2OXOA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2OXOA/PDBs_Clean/2OXOA.pdbA/Peeling/Peeling.log'},
#  {'id': 19,
#   'source': 'dataset',
#   'path': '../data/data_sword/3IC5A/PDBs_Clean/3IC5A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3IC5A/PDBs_Clean/3IC5A.pdbA/Peeling/Peeling.log'},
#  {'id': 20,
#   'source': 'dataset',
#   'path': '../data/data_sword/3Q9LA/PDBs_Clean/3Q9LA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3Q9LA/PDBs_Clean/3Q9LA.pdbA/Peeling/Peeling.log'},
#  {'id': 21,
#   'source': 'dataset',
#   'path': '../data/data_sword/1ZM8A/PDBs_Clean/1ZM8A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1ZM8A/PDBs_Clean/1ZM8A.pdbA/Peeling/Peeling.log'},
#  {'id': 22,
#   'source': 'dataset',
#   'path': '../data/data_sword/3EFBA/PDBs_Clean/3EFBA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3EFBA/PDBs_Clean/3EFBA.pdbA/Peeling/Peeling.log'},
#  {'id': 23,
#   'source': 'dataset',
#   'path': '../data/data_sword/2QGYA/PDBs_Clean/2QGYA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2QGYA/PDBs_Clean/2QGYA.pdbA/Peeling/Peeling.log'},
#  {'id': 24,
#   'source': 'dataset',
#   'path': '../data/data_sword/1UGIA/PDBs_Clean/1UGIA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1UGIA/PDBs_Clean/1UGIA.pdbA/Peeling/Peeling.log'},
#  {'id': 25,
#   'source': 'dataset',
#   'path': '../data/data_sword/4EZGA/PDBs_Clean/4EZGA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/4EZGA/PDBs_Clean/4EZGA.pdbA/Peeling/Peeling.log'},
#  {'id': 26,
#   'source': 'dataset',
#   'path': '../data/data_sword/3HI2B/PDBs_Clean/3HI2B.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/3HI2B/PDBs_Clean/3HI2B.pdbB/Peeling/Peeling.log'},
#  {'id': 27,
#   'source': 'dataset',
#   'path': '../data/data_sword/4GICA/PDBs_Clean/4GICA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/4GICA/PDBs_Clean/4GICA.pdbA/Peeling/Peeling.log'},
#  {'id': 28,
#   'source': 'dataset',
#   'path': '../data/data_sword/2OLTA/PDBs_Clean/2OLTA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2OLTA/PDBs_Clean/2OLTA.pdbA/Peeling/Peeling.log'},
#  {'id': 29,
#   'source': 'dataset',
#   'path': '../data/data_sword/1ORNA/PDBs_Clean/1ORNA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1ORNA/PDBs_Clean/1ORNA.pdbA/Peeling/Peeling.log'},
#  {'id': 30,
#   'source': 'dataset',
#   'path': '../data/data_sword/2OZTA/PDBs_Clean/2OZTA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2OZTA/PDBs_Clean/2OZTA.pdbA/Peeling/Peeling.log'},
#  {'id': 31,
#   'source': 'dataset',
#   'path': '../data/data_sword/3HDGA/PDBs_Clean/3HDGA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3HDGA/PDBs_Clean/3HDGA.pdbA/Peeling/Peeling.log'},
#  {'id': 32,
#   'source': 'dataset',
#   'path': '../data/data_sword/3HDCA/PDBs_Clean/3HDCA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3HDCA/PDBs_Clean/3HDCA.pdbA/Peeling/Peeling.log'},
#  {'id': 33,
#   'source': 'dataset',
#   'path': '../data/data_sword/3JTNA/PDBs_Clean/3JTNA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3JTNA/PDBs_Clean/3JTNA.pdbA/Peeling/Peeling.log'},
#  {'id': 34,
#   'source': 'dataset',
#   'path': '../data/data_sword/3SHOA/PDBs_Clean/3SHOA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3SHOA/PDBs_Clean/3SHOA.pdbA/Peeling/Peeling.log'},
#  {'id': 35,
#   'source': 'dataset',
#   'path': '../data/data_sword/3MI6A/PDBs_Clean/3MI6A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3MI6A/PDBs_Clean/3MI6A.pdbA/Peeling/Peeling.log'},
#  {'id': 36,
#   'source': 'dataset',
#   'path': '../data/data_sword/3C0FB/PDBs_Clean/3C0FB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/3C0FB/PDBs_Clean/3C0FB.pdbB/Peeling/Peeling.log'},
#  {'id': 37,
#   'source': 'dataset',
#   'path': '../data/data_sword/2ISNA/PDBs_Clean/2ISNA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2ISNA/PDBs_Clean/2ISNA.pdbA/Peeling/Peeling.log'},
#  {'id': 38,
#   'source': 'dataset',
#   'path': '../data/data_sword/1SJYA/PDBs_Clean/1SJYA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1SJYA/PDBs_Clean/1SJYA.pdbA/Peeling/Peeling.log'},
#  {'id': 39,
#   'source': 'dataset',
#   'path': '../data/data_sword/2OJ5A/PDBs_Clean/2OJ5A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2OJ5A/PDBs_Clean/2OJ5A.pdbA/Peeling/Peeling.log'},
#  {'id': 40,
#   'source': 'dataset',
#   'path': '../data/data_sword/2WTPA/PDBs_Clean/2WTPA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2WTPA/PDBs_Clean/2WTPA.pdbA/Peeling/Peeling.log'},
#  {'id': 41,
#   'source': 'dataset',
#   'path': '../data/data_sword/2FYXA/PDBs_Clean/2FYXA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2FYXA/PDBs_Clean/2FYXA.pdbA/Peeling/Peeling.log'},
#  {'id': 42,
#   'source': 'dataset',
#   'path': '../data/data_sword/2RA6A/PDBs_Clean/2RA6A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2RA6A/PDBs_Clean/2RA6A.pdbA/Peeling/Peeling.log'},
#  {'id': 43,
#   'source': 'dataset',
#   'path': '../data/data_sword/3C18A/PDBs_Clean/3C18A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3C18A/PDBs_Clean/3C18A.pdbA/Peeling/Peeling.log'},
#  {'id': 44,
#   'source': 'dataset',
#   'path': '../data/data_sword/1ZKLA/PDBs_Clean/1ZKLA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1ZKLA/PDBs_Clean/1ZKLA.pdbA/Peeling/Peeling.log'},
#  {'id': 45,
#   'source': 'dataset',
#   'path': '../data/data_sword/3K6IA/PDBs_Clean/3K6IA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3K6IA/PDBs_Clean/3K6IA.pdbA/Peeling/Peeling.log'},
#  {'id': 46,
#   'source': 'dataset',
#   'path': '../data/data_sword/3RL5A/PDBs_Clean/3RL5A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3RL5A/PDBs_Clean/3RL5A.pdbA/Peeling/Peeling.log'},
#  {'id': 47,
#   'source': 'dataset',
#   'path': '../data/data_sword/3PPBA/PDBs_Clean/3PPBA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3PPBA/PDBs_Clean/3PPBA.pdbA/Peeling/Peeling.log'},
#  {'id': 48,
#   'source': 'dataset',
#   'path': '../data/data_sword/2WFBA/PDBs_Clean/2WFBA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2WFBA/PDBs_Clean/2WFBA.pdbA/Peeling/Peeling.log'},
#  {'id': 49,
#   'source': 'dataset',
#   'path': '../data/data_sword/3AYRA/PDBs_Clean/3AYRA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3AYRA/PDBs_Clean/3AYRA.pdbA/Peeling/Peeling.log'},
#  {'id': 50,
#   'source': 'dataset',
#   'path': '../data/data_sword/2V8QB/PDBs_Clean/2V8QB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/2V8QB/PDBs_Clean/2V8QB.pdbB/Peeling/Peeling.log'},
#  {'id': 51,
#   'source': 'dataset',
#   'path': '../data/data_sword/1CC8A/PDBs_Clean/1CC8A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1CC8A/PDBs_Clean/1CC8A.pdbA/Peeling/Peeling.log'},
#  {'id': 52,
#   'source': 'dataset',
#   'path': '../data/data_sword/2FFMA/PDBs_Clean/2FFMA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2FFMA/PDBs_Clean/2FFMA.pdbA/Peeling/Peeling.log'},
#  {'id': 53,
#   'source': 'dataset',
#   'path': '../data/data_sword/3DXSX/PDBs_Clean/3DXSX.pdbX/file_proba_contact.mat',
#   'annot': '../data/data_sword/3DXSX/PDBs_Clean/3DXSX.pdbX/Peeling/Peeling.log'},
#  {'id': 54,
#   'source': 'dataset',
#   'path': '../data/data_sword/3RNQA/PDBs_Clean/3RNQA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3RNQA/PDBs_Clean/3RNQA.pdbA/Peeling/Peeling.log'},
#  {'id': 55,
#   'source': 'dataset',
#   'path': '../data/data_sword/3NTVA/PDBs_Clean/3NTVA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3NTVA/PDBs_Clean/3NTVA.pdbA/Peeling/Peeling.log'},
#  {'id': 56,
#   'source': 'dataset',
#   'path': '../data/data_sword/3FNRA/PDBs_Clean/3FNRA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3FNRA/PDBs_Clean/3FNRA.pdbA/Peeling/Peeling.log'},
#  {'id': 57,
#   'source': 'dataset',
#   'path': '../data/data_sword/2V2PA/PDBs_Clean/2V2PA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2V2PA/PDBs_Clean/2V2PA.pdbA/Peeling/Peeling.log'},
#  {'id': 58,
#   'source': 'dataset',
#   'path': '../data/data_sword/2R39A/PDBs_Clean/2R39A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2R39A/PDBs_Clean/2R39A.pdbA/Peeling/Peeling.log'},
#  {'id': 59,
#   'source': 'dataset',
#   'path': '../data/data_sword/1QI9A/PDBs_Clean/1QI9A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1QI9A/PDBs_Clean/1QI9A.pdbA/Peeling/Peeling.log'},
#  {'id': 60,
#   'source': 'dataset',
#   'path': '../data/data_sword/2FB0A/PDBs_Clean/2FB0A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2FB0A/PDBs_Clean/2FB0A.pdbA/Peeling/Peeling.log'},
#  {'id': 61,
#   'source': 'dataset',
#   'path': '../data/data_sword/3GWKC/PDBs_Clean/3GWKC.pdbC/file_proba_contact.mat',
#   'annot': '../data/data_sword/3GWKC/PDBs_Clean/3GWKC.pdbC/Peeling/Peeling.log'},
#  {'id': 62,
#   'source': 'dataset',
#   'path': '../data/data_sword/3MW9A/PDBs_Clean/3MW9A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3MW9A/PDBs_Clean/3MW9A.pdbA/Peeling/Peeling.log'},
#  {'id': 63,
#   'source': 'dataset',
#   'path': '../data/data_sword/3LVYA/PDBs_Clean/3LVYA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3LVYA/PDBs_Clean/3LVYA.pdbA/Peeling/Peeling.log'},
#  {'id': 64,
#   'source': 'dataset',
#   'path': '../data/data_sword/3OEEH/PDBs_Clean/3OEEH.pdbH/file_proba_contact.mat',
#   'annot': '../data/data_sword/3OEEH/PDBs_Clean/3OEEH.pdbH/Peeling/Peeling.log'},
#  {'id': 65,
#   'source': 'dataset',
#   'path': '../data/data_sword/3FSOA/PDBs_Clean/3FSOA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3FSOA/PDBs_Clean/3FSOA.pdbA/Peeling/Peeling.log'},
#  {'id': 66,
#   'source': 'dataset',
#   'path': '../data/data_sword/1XERA/PDBs_Clean/1XERA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1XERA/PDBs_Clean/1XERA.pdbA/Peeling/Peeling.log'},
#  {'id': 67,
#   'source': 'dataset',
#   'path': '../data/data_sword/1ZJCA/PDBs_Clean/1ZJCA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1ZJCA/PDBs_Clean/1ZJCA.pdbA/Peeling/Peeling.log'},
#  {'id': 68,
#   'source': 'dataset',
#   'path': '../data/data_sword/2E0QA/PDBs_Clean/2E0QA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2E0QA/PDBs_Clean/2E0QA.pdbA/Peeling/Peeling.log'},
#  {'id': 69,
#   'source': 'dataset',
#   'path': '../data/data_sword/3DUPA/PDBs_Clean/3DUPA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3DUPA/PDBs_Clean/3DUPA.pdbA/Peeling/Peeling.log'},
#  {'id': 70,
#   'source': 'dataset',
#   'path': '../data/data_sword/2R25A/PDBs_Clean/2R25A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2R25A/PDBs_Clean/2R25A.pdbA/Peeling/Peeling.log'},
#  {'id': 71,
#   'source': 'dataset',
#   'path': '../data/data_sword/3HN5A/PDBs_Clean/3HN5A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3HN5A/PDBs_Clean/3HN5A.pdbA/Peeling/Peeling.log'},
#  {'id': 72,
#   'source': 'dataset',
#   'path': '../data/data_sword/4AP4C/PDBs_Clean/4AP4C.pdbC/file_proba_contact.mat',
#   'annot': '../data/data_sword/4AP4C/PDBs_Clean/4AP4C.pdbC/Peeling/Peeling.log'},
#  {'id': 73,
#   'source': 'dataset',
#   'path': '../data/data_sword/3D6MB/PDBs_Clean/3D6MB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/3D6MB/PDBs_Clean/3D6MB.pdbB/Peeling/Peeling.log'},
#  {'id': 74,
#   'source': 'dataset',
#   'path': '../data/data_sword/2DT5A/PDBs_Clean/2DT5A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2DT5A/PDBs_Clean/2DT5A.pdbA/Peeling/Peeling.log'},
#  {'id': 75,
#   'source': 'dataset',
#   'path': '../data/data_sword/2GELA/PDBs_Clean/2GELA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2GELA/PDBs_Clean/2GELA.pdbA/Peeling/Peeling.log'},
#  {'id': 76,
#   'source': 'dataset',
#   'path': '../data/data_sword/3K8KA/PDBs_Clean/3K8KA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3K8KA/PDBs_Clean/3K8KA.pdbA/Peeling/Peeling.log'},
#  {'id': 77,
#   'source': 'dataset',
#   'path': '../data/data_sword/2YCFA/PDBs_Clean/2YCFA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2YCFA/PDBs_Clean/2YCFA.pdbA/Peeling/Peeling.log'},
#  {'id': 78,
#   'source': 'dataset',
#   'path': '../data/data_sword/3NX3A/PDBs_Clean/3NX3A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3NX3A/PDBs_Clean/3NX3A.pdbA/Peeling/Peeling.log'},
#  {'id': 79,
#   'source': 'dataset',
#   'path': '../data/data_sword/3BLZA/PDBs_Clean/3BLZA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3BLZA/PDBs_Clean/3BLZA.pdbA/Peeling/Peeling.log'},
#  {'id': 80,
#   'source': 'dataset',
#   'path': '../data/data_sword/2VB1A/PDBs_Clean/2VB1A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2VB1A/PDBs_Clean/2VB1A.pdbA/Peeling/Peeling.log'},
#  {'id': 81,
#   'source': 'dataset',
#   'path': '../data/data_sword/3CJNA/PDBs_Clean/3CJNA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3CJNA/PDBs_Clean/3CJNA.pdbA/Peeling/Peeling.log'},
#  {'id': 82,
#   'source': 'dataset',
#   'path': '../data/data_sword/2A9GA/PDBs_Clean/2A9GA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2A9GA/PDBs_Clean/2A9GA.pdbA/Peeling/Peeling.log'},
#  {'id': 83,
#   'source': 'dataset',
#   'path': '../data/data_sword/2HIHA/PDBs_Clean/2HIHA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2HIHA/PDBs_Clean/2HIHA.pdbA/Peeling/Peeling.log'},
#  {'id': 84,
#   'source': 'dataset',
#   'path': '../data/data_sword/4G4SO/PDBs_Clean/4G4SO.pdbO/file_proba_contact.mat',
#   'annot': '../data/data_sword/4G4SO/PDBs_Clean/4G4SO.pdbO/Peeling/Peeling.log'},
#  {'id': 85,
#   'source': 'dataset',
#   'path': '../data/data_sword/3NDHA/PDBs_Clean/3NDHA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3NDHA/PDBs_Clean/3NDHA.pdbA/Peeling/Peeling.log'},
#  {'id': 86,
#   'source': 'dataset',
#   'path': '../data/data_sword/2Q0ZX/PDBs_Clean/2Q0ZX.pdbX/file_proba_contact.mat',
#   'annot': '../data/data_sword/2Q0ZX/PDBs_Clean/2Q0ZX.pdbX/Peeling/Peeling.log'},
#  {'id': 87,
#   'source': 'dataset',
#   'path': '../data/data_sword/3NSWA/PDBs_Clean/3NSWA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3NSWA/PDBs_Clean/3NSWA.pdbA/Peeling/Peeling.log'},
#  {'id': 88,
#   'source': 'dataset',
#   'path': '../data/data_sword/1CUNA/PDBs_Clean/1CUNA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1CUNA/PDBs_Clean/1CUNA.pdbA/Peeling/Peeling.log'},
#  {'id': 89,
#   'source': 'dataset',
#   'path': '../data/data_sword/1IDPA/PDBs_Clean/1IDPA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1IDPA/PDBs_Clean/1IDPA.pdbA/Peeling/Peeling.log'},
#  {'id': 90,
#   'source': 'dataset',
#   'path': '../data/data_sword/3LWCA/PDBs_Clean/3LWCA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3LWCA/PDBs_Clean/3LWCA.pdbA/Peeling/Peeling.log'},
#  {'id': 91,
#   'source': 'dataset',
#   'path': '../data/data_sword/1J3AA/PDBs_Clean/1J3AA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1J3AA/PDBs_Clean/1J3AA.pdbA/Peeling/Peeling.log'},
#  {'id': 92,
#   'source': 'dataset',
#   'path': '../data/data_sword/4F3LA/PDBs_Clean/4F3LA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/4F3LA/PDBs_Clean/4F3LA.pdbA/Peeling/Peeling.log'},
#  {'id': 93,
#   'source': 'dataset',
#   'path': '../data/data_sword/3QQ2A/PDBs_Clean/3QQ2A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3QQ2A/PDBs_Clean/3QQ2A.pdbA/Peeling/Peeling.log'},
#  {'id': 94,
#   'source': 'dataset',
#   'path': '../data/data_sword/2II2A/PDBs_Clean/2II2A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2II2A/PDBs_Clean/2II2A.pdbA/Peeling/Peeling.log'},
#  {'id': 95,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GZ2A/PDBs_Clean/1GZ2A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GZ2A/PDBs_Clean/1GZ2A.pdbA/Peeling/Peeling.log'},
#  {'id': 96,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EK6A/PDBs_Clean/1EK6A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EK6A/PDBs_Clean/1EK6A.pdbA/Peeling/Peeling.log'},
#  {'id': 97,
#   'source': 'dataset',
#   'path': '../data/data_sword/3MUJA/PDBs_Clean/3MUJA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3MUJA/PDBs_Clean/3MUJA.pdbA/Peeling/Peeling.log'},
#  {'id': 98,
#   'source': 'dataset',
#   'path': '../data/data_sword/2V76A/PDBs_Clean/2V76A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2V76A/PDBs_Clean/2V76A.pdbA/Peeling/Peeling.log'},
#  {'id': 99,
#   'source': 'dataset',
#   'path': '../data/data_sword/3M1TA/PDBs_Clean/3M1TA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3M1TA/PDBs_Clean/3M1TA.pdbA/Peeling/Peeling.log'},
#  {'id': 100,
#   'source': 'dataset',
#   'path': '../data/data_sword/2W43A/PDBs_Clean/2W43A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2W43A/PDBs_Clean/2W43A.pdbA/Peeling/Peeling.log'},
#  {'id': 101,
#   'source': 'dataset',
#   'path': '../data/data_sword/1R4VA/PDBs_Clean/1R4VA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1R4VA/PDBs_Clean/1R4VA.pdbA/Peeling/Peeling.log'},
#  {'id': 102,
#   'source': 'dataset',
#   'path': '../data/data_sword/2FU4A/PDBs_Clean/2FU4A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2FU4A/PDBs_Clean/2FU4A.pdbA/Peeling/Peeling.log'},
#  {'id': 103,
#   'source': 'dataset',
#   'path': '../data/data_sword/4H9NC/PDBs_Clean/4H9NC.pdbC/file_proba_contact.mat',
#   'annot': '../data/data_sword/4H9NC/PDBs_Clean/4H9NC.pdbC/Peeling/Peeling.log'},
#  {'id': 104,
#   'source': 'dataset',
#   'path': '../data/data_sword/3JWPA/PDBs_Clean/3JWPA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3JWPA/PDBs_Clean/3JWPA.pdbA/Peeling/Peeling.log'},
#  {'id': 105,
#   'source': 'dataset',
#   'path': '../data/data_sword/3ETJA/PDBs_Clean/3ETJA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3ETJA/PDBs_Clean/3ETJA.pdbA/Peeling/Peeling.log'},
#  {'id': 106,
#   'source': 'dataset',
#   'path': '../data/data_sword/3OCJA/PDBs_Clean/3OCJA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3OCJA/PDBs_Clean/3OCJA.pdbA/Peeling/Peeling.log'},
#  {'id': 107,
#   'source': 'dataset',
#   'path': '../data/data_sword/3D1BA/PDBs_Clean/3D1BA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3D1BA/PDBs_Clean/3D1BA.pdbA/Peeling/Peeling.log'},
#  {'id': 108,
#   'source': 'dataset',
#   'path': '../data/data_sword/1V7RA/PDBs_Clean/1V7RA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1V7RA/PDBs_Clean/1V7RA.pdbA/Peeling/Peeling.log'},
#  {'id': 109,
#   'source': 'dataset',
#   'path': '../data/data_sword/2VFXA/PDBs_Clean/2VFXA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2VFXA/PDBs_Clean/2VFXA.pdbA/Peeling/Peeling.log'},
#  {'id': 110,
#   'source': 'dataset',
#   'path': '../data/data_sword/1W98B/PDBs_Clean/1W98B.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/1W98B/PDBs_Clean/1W98B.pdbB/Peeling/Peeling.log'},
#  {'id': 111,
#   'source': 'dataset',
#   'path': '../data/data_sword/3GRDA/PDBs_Clean/3GRDA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3GRDA/PDBs_Clean/3GRDA.pdbA/Peeling/Peeling.log'},
#  {'id': 112,
#   'source': 'dataset',
#   'path': '../data/data_sword/2DDXA/PDBs_Clean/2DDXA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2DDXA/PDBs_Clean/2DDXA.pdbA/Peeling/Peeling.log'},
#  {'id': 113,
#   'source': 'dataset',
#   'path': '../data/data_sword/2HX0A/PDBs_Clean/2HX0A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2HX0A/PDBs_Clean/2HX0A.pdbA/Peeling/Peeling.log'},
#  {'id': 114,
#   'source': 'dataset',
#   'path': '../data/data_sword/1NLQA/PDBs_Clean/1NLQA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1NLQA/PDBs_Clean/1NLQA.pdbA/Peeling/Peeling.log'},
#  {'id': 115,
#   'source': 'dataset',
#   'path': '../data/data_sword/3BO5A/PDBs_Clean/3BO5A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3BO5A/PDBs_Clean/3BO5A.pdbA/Peeling/Peeling.log'},
#  {'id': 116,
#   'source': 'dataset',
#   'path': '../data/data_sword/4EYBA/PDBs_Clean/4EYBA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/4EYBA/PDBs_Clean/4EYBA.pdbA/Peeling/Peeling.log'},
#  {'id': 117,
#   'source': 'dataset',
#   'path': '../data/data_sword/4DGUA/PDBs_Clean/4DGUA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/4DGUA/PDBs_Clean/4DGUA.pdbA/Peeling/Peeling.log'},
#  {'id': 118,
#   'source': 'dataset',
#   'path': '../data/data_sword/3R4RA/PDBs_Clean/3R4RA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3R4RA/PDBs_Clean/3R4RA.pdbA/Peeling/Peeling.log'},
#  {'id': 119,
#   'source': 'dataset',
#   'path': '../data/data_sword/3GMOA/PDBs_Clean/3GMOA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3GMOA/PDBs_Clean/3GMOA.pdbA/Peeling/Peeling.log'},
#  {'id': 120,
#   'source': 'dataset',
#   'path': '../data/data_sword/2Q3MA/PDBs_Clean/2Q3MA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2Q3MA/PDBs_Clean/2Q3MA.pdbA/Peeling/Peeling.log'},
#  {'id': 121,
#   'source': 'dataset',
#   'path': '../data/data_sword/3NA5A/PDBs_Clean/3NA5A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3NA5A/PDBs_Clean/3NA5A.pdbA/Peeling/Peeling.log'},
#  {'id': 122,
#   'source': 'dataset',
#   'path': '../data/data_sword/1T2DA/PDBs_Clean/1T2DA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1T2DA/PDBs_Clean/1T2DA.pdbA/Peeling/Peeling.log'},
#  {'id': 123,
#   'source': 'dataset',
#   'path': '../data/data_sword/1AX8A/PDBs_Clean/1AX8A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1AX8A/PDBs_Clean/1AX8A.pdbA/Peeling/Peeling.log'},
#  {'id': 124,
#   'source': 'dataset',
#   'path': '../data/data_sword/1K04A/PDBs_Clean/1K04A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1K04A/PDBs_Clean/1K04A.pdbA/Peeling/Peeling.log'},
#  {'id': 125,
#   'source': 'dataset',
#   'path': '../data/data_sword/3FCGA/PDBs_Clean/3FCGA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3FCGA/PDBs_Clean/3FCGA.pdbA/Peeling/Peeling.log'},
#  {'id': 126,
#   'source': 'dataset',
#   'path': '../data/data_sword/2E0NA/PDBs_Clean/2E0NA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2E0NA/PDBs_Clean/2E0NA.pdbA/Peeling/Peeling.log'},
#  {'id': 127,
#   'source': 'dataset',
#   'path': '../data/data_sword/2R19A/PDBs_Clean/2R19A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2R19A/PDBs_Clean/2R19A.pdbA/Peeling/Peeling.log'},
#  {'id': 128,
#   'source': 'dataset',
#   'path': '../data/data_sword/1LWBA/PDBs_Clean/1LWBA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1LWBA/PDBs_Clean/1LWBA.pdbA/Peeling/Peeling.log'},
#  {'id': 129,
#   'source': 'dataset',
#   'path': '../data/data_sword/3SWKA/PDBs_Clean/3SWKA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3SWKA/PDBs_Clean/3SWKA.pdbA/Peeling/Peeling.log'},
#  {'id': 130,
#   'source': 'dataset',
#   'path': '../data/data_sword/2WBTA/PDBs_Clean/2WBTA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2WBTA/PDBs_Clean/2WBTA.pdbA/Peeling/Peeling.log'},
#  {'id': 131,
#   'source': 'dataset',
#   'path': '../data/data_sword/2Q07A/PDBs_Clean/2Q07A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2Q07A/PDBs_Clean/2Q07A.pdbA/Peeling/Peeling.log'},
#  {'id': 132,
#   'source': 'dataset',
#   'path': '../data/data_sword/1U0JA/PDBs_Clean/1U0JA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1U0JA/PDBs_Clean/1U0JA.pdbA/Peeling/Peeling.log'},
#  {'id': 133,
#   'source': 'dataset',
#   'path': '../data/data_sword/3IDWA/PDBs_Clean/3IDWA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3IDWA/PDBs_Clean/3IDWA.pdbA/Peeling/Peeling.log'},
#  {'id': 134,
#   'source': 'dataset',
#   'path': '../data/data_sword/3EIPA/PDBs_Clean/3EIPA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3EIPA/PDBs_Clean/3EIPA.pdbA/Peeling/Peeling.log'},
#  {'id': 135,
#   'source': 'dataset',
#   'path': '../data/data_sword/3KAWA/PDBs_Clean/3KAWA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3KAWA/PDBs_Clean/3KAWA.pdbA/Peeling/Peeling.log'},
#  {'id': 136,
#   'source': 'dataset',
#   'path': '../data/data_sword/3A4RA/PDBs_Clean/3A4RA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3A4RA/PDBs_Clean/3A4RA.pdbA/Peeling/Peeling.log'},
#  {'id': 137,
#   'source': 'dataset',
#   'path': '../data/data_sword/3MEPA/PDBs_Clean/3MEPA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3MEPA/PDBs_Clean/3MEPA.pdbA/Peeling/Peeling.log'},
#  {'id': 138,
#   'source': 'dataset',
#   'path': '../data/data_sword/2J8HA/PDBs_Clean/2J8HA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2J8HA/PDBs_Clean/2J8HA.pdbA/Peeling/Peeling.log'},
#  {'id': 139,
#   'source': 'dataset',
#   'path': '../data/data_sword/3QK8A/PDBs_Clean/3QK8A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3QK8A/PDBs_Clean/3QK8A.pdbA/Peeling/Peeling.log'},
#  {'id': 140,
#   'source': 'dataset',
#   'path': '../data/data_sword/3DMCA/PDBs_Clean/3DMCA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3DMCA/PDBs_Clean/3DMCA.pdbA/Peeling/Peeling.log'},
#  {'id': 141,
#   'source': 'dataset',
#   'path': '../data/data_sword/3FHKA/PDBs_Clean/3FHKA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3FHKA/PDBs_Clean/3FHKA.pdbA/Peeling/Peeling.log'},
#  {'id': 142,
#   'source': 'dataset',
#   'path': '../data/data_sword/3DNFA/PDBs_Clean/3DNFA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3DNFA/PDBs_Clean/3DNFA.pdbA/Peeling/Peeling.log'},
#  {'id': 143,
#   'source': 'dataset',
#   'path': '../data/data_sword/4G2AA/PDBs_Clean/4G2AA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/4G2AA/PDBs_Clean/4G2AA.pdbA/Peeling/Peeling.log'},
#  {'id': 144,
#   'source': 'dataset',
#   'path': '../data/data_sword/3MNMA/PDBs_Clean/3MNMA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3MNMA/PDBs_Clean/3MNMA.pdbA/Peeling/Peeling.log'},
#  {'id': 145,
#   'source': 'dataset',
#   'path': '../data/data_sword/2Q3QA/PDBs_Clean/2Q3QA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2Q3QA/PDBs_Clean/2Q3QA.pdbA/Peeling/Peeling.log'},
#  {'id': 146,
#   'source': 'dataset',
#   'path': '../data/data_sword/1I7DA/PDBs_Clean/1I7DA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1I7DA/PDBs_Clean/1I7DA.pdbA/Peeling/Peeling.log'},
#  {'id': 147,
#   'source': 'dataset',
#   'path': '../data/data_sword/2P8EA/PDBs_Clean/2P8EA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2P8EA/PDBs_Clean/2P8EA.pdbA/Peeling/Peeling.log'},
#  {'id': 148,
#   'source': 'dataset',
#   'path': '../data/data_sword/3MZKB/PDBs_Clean/3MZKB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/3MZKB/PDBs_Clean/3MZKB.pdbB/Peeling/Peeling.log'},
#  {'id': 149,
#   'source': 'dataset',
#   'path': '../data/data_sword/1YLMA/PDBs_Clean/1YLMA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1YLMA/PDBs_Clean/1YLMA.pdbA/Peeling/Peeling.log'},
#  {'id': 150,
#   'source': 'dataset',
#   'path': '../data/data_sword/2QYCA/PDBs_Clean/2QYCA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2QYCA/PDBs_Clean/2QYCA.pdbA/Peeling/Peeling.log'},
#  {'id': 151,
#   'source': 'dataset',
#   'path': '../data/data_sword/3QXZA/PDBs_Clean/3QXZA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3QXZA/PDBs_Clean/3QXZA.pdbA/Peeling/Peeling.log'},
#  {'id': 152,
#   'source': 'dataset',
#   'path': '../data/data_sword/2P08A/PDBs_Clean/2P08A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2P08A/PDBs_Clean/2P08A.pdbA/Peeling/Peeling.log'},
#  {'id': 153,
#   'source': 'dataset',
#   'path': '../data/data_sword/2II0A/PDBs_Clean/2II0A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2II0A/PDBs_Clean/2II0A.pdbA/Peeling/Peeling.log'},
#  {'id': 154,
#   'source': 'dataset',
#   'path': '../data/data_sword/3K3CA/PDBs_Clean/3K3CA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3K3CA/PDBs_Clean/3K3CA.pdbA/Peeling/Peeling.log'},
#  {'id': 155,
#   'source': 'dataset',
#   'path': '../data/data_sword/3TNJA/PDBs_Clean/3TNJA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3TNJA/PDBs_Clean/3TNJA.pdbA/Peeling/Peeling.log'},
#  {'id': 156,
#   'source': 'dataset',
#   'path': '../data/data_sword/1JFIB/PDBs_Clean/1JFIB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/1JFIB/PDBs_Clean/1JFIB.pdbB/Peeling/Peeling.log'},
#  {'id': 157,
#   'source': 'dataset',
#   'path': '../data/data_sword/2XWUB/PDBs_Clean/2XWUB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/2XWUB/PDBs_Clean/2XWUB.pdbB/Peeling/Peeling.log'},
#  {'id': 158,
#   'source': 'dataset',
#   'path': '../data/data_sword/3CECA/PDBs_Clean/3CECA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3CECA/PDBs_Clean/3CECA.pdbA/Peeling/Peeling.log'},
#  {'id': 159,
#   'source': 'dataset',
#   'path': '../data/data_sword/3FLHA/PDBs_Clean/3FLHA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3FLHA/PDBs_Clean/3FLHA.pdbA/Peeling/Peeling.log'},
#  {'id': 160,
#   'source': 'dataset',
#   'path': '../data/data_sword/1Y07A/PDBs_Clean/1Y07A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1Y07A/PDBs_Clean/1Y07A.pdbA/Peeling/Peeling.log'},
#  {'id': 161,
#   'source': 'dataset',
#   'path': '../data/data_sword/1B89A/PDBs_Clean/1B89A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1B89A/PDBs_Clean/1B89A.pdbA/Peeling/Peeling.log'},
#  {'id': 162,
#   'source': 'dataset',
#   'path': '../data/data_sword/2DBSA/PDBs_Clean/2DBSA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2DBSA/PDBs_Clean/2DBSA.pdbA/Peeling/Peeling.log'},
#  {'id': 163,
#   'source': 'dataset',
#   'path': '../data/data_sword/2NWIA/PDBs_Clean/2NWIA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2NWIA/PDBs_Clean/2NWIA.pdbA/Peeling/Peeling.log'},
#  {'id': 164,
#   'source': 'dataset',
#   'path': '../data/data_sword/1DOWA/PDBs_Clean/1DOWA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1DOWA/PDBs_Clean/1DOWA.pdbA/Peeling/Peeling.log'},
#  {'id': 165,
#   'source': 'dataset',
#   'path': '../data/data_sword/3FJVA/PDBs_Clean/3FJVA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3FJVA/PDBs_Clean/3FJVA.pdbA/Peeling/Peeling.log'},
#  {'id': 166,
#   'source': 'dataset',
#   'path': '../data/data_sword/1IUJA/PDBs_Clean/1IUJA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1IUJA/PDBs_Clean/1IUJA.pdbA/Peeling/Peeling.log'},
#  {'id': 167,
#   'source': 'dataset',
#   'path': '../data/data_sword/3GVXA/PDBs_Clean/3GVXA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3GVXA/PDBs_Clean/3GVXA.pdbA/Peeling/Peeling.log'},
#  {'id': 168,
#   'source': 'dataset',
#   'path': '../data/data_sword/3NS4A/PDBs_Clean/3NS4A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3NS4A/PDBs_Clean/3NS4A.pdbA/Peeling/Peeling.log'},
#  {'id': 169,
#   'source': 'dataset',
#   'path': '../data/data_sword/3DWGC/PDBs_Clean/3DWGC.pdbC/file_proba_contact.mat',
#   'annot': '../data/data_sword/3DWGC/PDBs_Clean/3DWGC.pdbC/Peeling/Peeling.log'},
#  {'id': 170,
#   'source': 'dataset',
#   'path': '../data/data_sword/1NE8A/PDBs_Clean/1NE8A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1NE8A/PDBs_Clean/1NE8A.pdbA/Peeling/Peeling.log'},
#  {'id': 171,
#   'source': 'dataset',
#   'path': '../data/data_sword/3AVRA/PDBs_Clean/3AVRA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3AVRA/PDBs_Clean/3AVRA.pdbA/Peeling/Peeling.log'},
#  {'id': 172,
#   'source': 'dataset',
#   'path': '../data/data_sword/3KRAB/PDBs_Clean/3KRAB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/3KRAB/PDBs_Clean/3KRAB.pdbB/Peeling/Peeling.log'},
#  {'id': 173,
#   'source': 'dataset',
#   'path': '../data/data_sword/2ZYZB/PDBs_Clean/2ZYZB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/2ZYZB/PDBs_Clean/2ZYZB.pdbB/Peeling/Peeling.log'},
#  {'id': 174,
#   'source': 'dataset',
#   'path': '../data/data_sword/1HW1A/PDBs_Clean/1HW1A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1HW1A/PDBs_Clean/1HW1A.pdbA/Peeling/Peeling.log'},
#  {'id': 175,
#   'source': 'dataset',
#   'path': '../data/data_sword/4E0QA/PDBs_Clean/4E0QA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/4E0QA/PDBs_Clean/4E0QA.pdbA/Peeling/Peeling.log'},
#  {'id': 176,
#   'source': 'dataset',
#   'path': '../data/data_sword/3HM5A/PDBs_Clean/3HM5A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3HM5A/PDBs_Clean/3HM5A.pdbA/Peeling/Peeling.log'},
#  {'id': 177,
#   'source': 'dataset',
#   'path': '../data/data_sword/2CMEB/PDBs_Clean/2CMEB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/2CMEB/PDBs_Clean/2CMEB.pdbB/Peeling/Peeling.log'},
#  {'id': 178,
#   'source': 'dataset',
#   'path': '../data/data_sword/2O99A/PDBs_Clean/2O99A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2O99A/PDBs_Clean/2O99A.pdbA/Peeling/Peeling.log'},
#  {'id': 179,
#   'source': 'dataset',
#   'path': '../data/data_sword/2EK0A/PDBs_Clean/2EK0A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2EK0A/PDBs_Clean/2EK0A.pdbA/Peeling/Peeling.log'},
#  {'id': 180,
#   'source': 'dataset',
#   'path': '../data/data_sword/1AHOA/PDBs_Clean/1AHOA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1AHOA/PDBs_Clean/1AHOA.pdbA/Peeling/Peeling.log'},
#  {'id': 181,
#   'source': 'dataset',
#   'path': '../data/data_sword/3ED4A/PDBs_Clean/3ED4A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3ED4A/PDBs_Clean/3ED4A.pdbA/Peeling/Peeling.log'},
#  {'id': 182,
#   'source': 'dataset',
#   'path': '../data/data_sword/3M7HA/PDBs_Clean/3M7HA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3M7HA/PDBs_Clean/3M7HA.pdbA/Peeling/Peeling.log'},
#  {'id': 183,
#   'source': 'dataset',
#   'path': '../data/data_sword/2XW6A/PDBs_Clean/2XW6A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2XW6A/PDBs_Clean/2XW6A.pdbA/Peeling/Peeling.log'},
#  {'id': 184,
#   'source': 'dataset',
#   'path': '../data/data_sword/3CNRA/PDBs_Clean/3CNRA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3CNRA/PDBs_Clean/3CNRA.pdbA/Peeling/Peeling.log'},
#  {'id': 185,
#   'source': 'dataset',
#   'path': '../data/data_sword/3AJWA/PDBs_Clean/3AJWA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3AJWA/PDBs_Clean/3AJWA.pdbA/Peeling/Peeling.log'},
#  {'id': 186,
#   'source': 'dataset',
#   'path': '../data/data_sword/1UEBA/PDBs_Clean/1UEBA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1UEBA/PDBs_Clean/1UEBA.pdbA/Peeling/Peeling.log'},
#  {'id': 187,
#   'source': 'dataset',
#   'path': '../data/data_sword/2QQ4A/PDBs_Clean/2QQ4A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2QQ4A/PDBs_Clean/2QQ4A.pdbA/Peeling/Peeling.log'},
#  {'id': 188,
#   'source': 'dataset',
#   'path': '../data/data_sword/1YM5A/PDBs_Clean/1YM5A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1YM5A/PDBs_Clean/1YM5A.pdbA/Peeling/Peeling.log'},
#  {'id': 189,
#   'source': 'dataset',
#   'path': '../data/data_sword/1BGCA/PDBs_Clean/1BGCA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1BGCA/PDBs_Clean/1BGCA.pdbA/Peeling/Peeling.log'},
#  {'id': 190,
#   'source': 'dataset',
#   'path': '../data/data_sword/3KLRA/PDBs_Clean/3KLRA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3KLRA/PDBs_Clean/3KLRA.pdbA/Peeling/Peeling.log'},
#  {'id': 191,
#   'source': 'dataset',
#   'path': '../data/data_sword/3PDYA/PDBs_Clean/3PDYA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3PDYA/PDBs_Clean/3PDYA.pdbA/Peeling/Peeling.log'},
#  {'id': 192,
#   'source': 'dataset',
#   'path': '../data/data_sword/2R4QA/PDBs_Clean/2R4QA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2R4QA/PDBs_Clean/2R4QA.pdbA/Peeling/Peeling.log'},
#  {'id': 193,
#   'source': 'dataset',
#   'path': '../data/data_sword/3GIRA/PDBs_Clean/3GIRA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3GIRA/PDBs_Clean/3GIRA.pdbA/Peeling/Peeling.log'},
#  {'id': 194,
#   'source': 'dataset',
#   'path': '../data/data_sword/1SMPI/PDBs_Clean/1SMPI.pdbI/file_proba_contact.mat',
#   'annot': '../data/data_sword/1SMPI/PDBs_Clean/1SMPI.pdbI/Peeling/Peeling.log'},
#  {'id': 195,
#   'source': 'dataset',
#   'path': '../data/data_sword/1UZKA/PDBs_Clean/1UZKA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1UZKA/PDBs_Clean/1UZKA.pdbA/Peeling/Peeling.log'},
#  {'id': 196,
#   'source': 'dataset',
#   'path': '../data/data_sword/3LLKA/PDBs_Clean/3LLKA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3LLKA/PDBs_Clean/3LLKA.pdbA/Peeling/Peeling.log'},
#  {'id': 197,
#   'source': 'dataset',
#   'path': '../data/data_sword/3DNSA/PDBs_Clean/3DNSA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3DNSA/PDBs_Clean/3DNSA.pdbA/Peeling/Peeling.log'},
#  {'id': 198,
#   'source': 'dataset',
#   'path': '../data/data_sword/1G55A/PDBs_Clean/1G55A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1G55A/PDBs_Clean/1G55A.pdbA/Peeling/Peeling.log'},
#  {'id': 199,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EDGA/PDBs_Clean/1EDGA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EDGA/PDBs_Clean/1EDGA.pdbA/Peeling/Peeling.log'},
#  {'id': 200,
#   'source': 'dataset',
#   'path': '../data/data_sword/2GA1A/PDBs_Clean/2GA1A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2GA1A/PDBs_Clean/2GA1A.pdbA/Peeling/Peeling.log'},
#  {'id': 201,
#   'source': 'dataset',
#   'path': '../data/data_sword/1PC4A/PDBs_Clean/1PC4A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1PC4A/PDBs_Clean/1PC4A.pdbA/Peeling/Peeling.log'},
#  {'id': 202,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EM9A/PDBs_Clean/1EM9A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EM9A/PDBs_Clean/1EM9A.pdbA/Peeling/Peeling.log'},
#  {'id': 203,
#   'source': 'dataset',
#   'path': '../data/data_sword/2XN6A/PDBs_Clean/2XN6A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2XN6A/PDBs_Clean/2XN6A.pdbA/Peeling/Peeling.log'},
#  {'id': 204,
#   'source': 'dataset',
#   'path': '../data/data_sword/3RFEA/PDBs_Clean/3RFEA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3RFEA/PDBs_Clean/3RFEA.pdbA/Peeling/Peeling.log'},
#  {'id': 205,
#   'source': 'dataset',
#   'path': '../data/data_sword/3AKSA/PDBs_Clean/3AKSA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3AKSA/PDBs_Clean/3AKSA.pdbA/Peeling/Peeling.log'},
#  {'id': 206,
#   'source': 'dataset',
#   'path': '../data/data_sword/2CYEA/PDBs_Clean/2CYEA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2CYEA/PDBs_Clean/2CYEA.pdbA/Peeling/Peeling.log'},
#  {'id': 207,
#   'source': 'dataset',
#   'path': '../data/data_sword/3GQHA/PDBs_Clean/3GQHA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3GQHA/PDBs_Clean/3GQHA.pdbA/Peeling/Peeling.log'},
#  {'id': 208,
#   'source': 'dataset',
#   'path': '../data/data_sword/3OSTA/PDBs_Clean/3OSTA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3OSTA/PDBs_Clean/3OSTA.pdbA/Peeling/Peeling.log'},
#  {'id': 209,
#   'source': 'dataset',
#   'path': '../data/data_sword/3PZ6A/PDBs_Clean/3PZ6A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3PZ6A/PDBs_Clean/3PZ6A.pdbA/Peeling/Peeling.log'},
#  {'id': 210,
#   'source': 'dataset',
#   'path': '../data/data_sword/2WQPA/PDBs_Clean/2WQPA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2WQPA/PDBs_Clean/2WQPA.pdbA/Peeling/Peeling.log'},
#  {'id': 211,
#   'source': 'dataset',
#   'path': '../data/data_sword/2QEDA/PDBs_Clean/2QEDA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2QEDA/PDBs_Clean/2QEDA.pdbA/Peeling/Peeling.log'},
#  {'id': 212,
#   'source': 'dataset',
#   'path': '../data/data_sword/2I46A/PDBs_Clean/2I46A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2I46A/PDBs_Clean/2I46A.pdbA/Peeling/Peeling.log'},
#  {'id': 213,
#   'source': 'dataset',
#   'path': '../data/data_sword/3OF4A/PDBs_Clean/3OF4A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3OF4A/PDBs_Clean/3OF4A.pdbA/Peeling/Peeling.log'},
#  {'id': 214,
#   'source': 'dataset',
#   'path': '../data/data_sword/2Q97T/PDBs_Clean/2Q97T.pdbT/file_proba_contact.mat',
#   'annot': '../data/data_sword/2Q97T/PDBs_Clean/2Q97T.pdbT/Peeling/Peeling.log'},
#  {'id': 215,
#   'source': 'dataset',
#   'path': '../data/data_sword/1WMZA/PDBs_Clean/1WMZA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1WMZA/PDBs_Clean/1WMZA.pdbA/Peeling/Peeling.log'},
#  {'id': 216,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BK8A/PDBs_Clean/2BK8A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BK8A/PDBs_Clean/2BK8A.pdbA/Peeling/Peeling.log'},
#  {'id': 217,
#   'source': 'dataset',
#   'path': '../data/data_sword/3K13A/PDBs_Clean/3K13A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3K13A/PDBs_Clean/3K13A.pdbA/Peeling/Peeling.log'},
#  {'id': 218,
#   'source': 'dataset',
#   'path': '../data/data_sword/2DSYA/PDBs_Clean/2DSYA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2DSYA/PDBs_Clean/2DSYA.pdbA/Peeling/Peeling.log'},
#  {'id': 219,
#   'source': 'dataset',
#   'path': '../data/data_sword/2R5UA/PDBs_Clean/2R5UA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2R5UA/PDBs_Clean/2R5UA.pdbA/Peeling/Peeling.log'},
#  {'id': 220,
#   'source': 'dataset',
#   'path': '../data/data_sword/2Z6VA/PDBs_Clean/2Z6VA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2Z6VA/PDBs_Clean/2Z6VA.pdbA/Peeling/Peeling.log'},
#  {'id': 221,
#   'source': 'dataset',
#   'path': '../data/data_sword/1TC5A/PDBs_Clean/1TC5A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1TC5A/PDBs_Clean/1TC5A.pdbA/Peeling/Peeling.log'},
#  {'id': 222,
#   'source': 'dataset',
#   'path': '../data/data_sword/3D33A/PDBs_Clean/3D33A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3D33A/PDBs_Clean/3D33A.pdbA/Peeling/Peeling.log'},
#  {'id': 223,
#   'source': 'dataset',
#   'path': '../data/data_sword/1HZ6A/PDBs_Clean/1HZ6A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1HZ6A/PDBs_Clean/1HZ6A.pdbA/Peeling/Peeling.log'},
#  {'id': 224,
#   'source': 'dataset',
#   'path': '../data/data_sword/1YRKA/PDBs_Clean/1YRKA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1YRKA/PDBs_Clean/1YRKA.pdbA/Peeling/Peeling.log'},
#  {'id': 225,
#   'source': 'dataset',
#   'path': '../data/data_sword/1BTNA/PDBs_Clean/1BTNA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1BTNA/PDBs_Clean/1BTNA.pdbA/Peeling/Peeling.log'},
#  {'id': 226,
#   'source': 'dataset',
#   'path': '../data/data_sword/3IP0A/PDBs_Clean/3IP0A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3IP0A/PDBs_Clean/3IP0A.pdbA/Peeling/Peeling.log'},
#  {'id': 227,
#   'source': 'dataset',
#   'path': '../data/data_sword/2VSMB/PDBs_Clean/2VSMB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/2VSMB/PDBs_Clean/2VSMB.pdbB/Peeling/Peeling.log'},
#  {'id': 228,
#   'source': 'dataset',
#   'path': '../data/data_sword/3Q7MA/PDBs_Clean/3Q7MA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3Q7MA/PDBs_Clean/3Q7MA.pdbA/Peeling/Peeling.log'},
#  {'id': 229,
#   'source': 'dataset',
#   'path': '../data/data_sword/1QQP2/PDBs_Clean/1QQP2.pdb2/file_proba_contact.mat',
#   'annot': '../data/data_sword/1QQP2/PDBs_Clean/1QQP2.pdb2/Peeling/Peeling.log'},
#  {'id': 230,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EJ8A/PDBs_Clean/1EJ8A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EJ8A/PDBs_Clean/1EJ8A.pdbA/Peeling/Peeling.log'},
#  {'id': 231,
#   'source': 'dataset',
#   'path': '../data/data_sword/3H4NA/PDBs_Clean/3H4NA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3H4NA/PDBs_Clean/3H4NA.pdbA/Peeling/Peeling.log'},
#  {'id': 232,
#   'source': 'dataset',
#   'path': '../data/data_sword/3LTJA/PDBs_Clean/3LTJA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3LTJA/PDBs_Clean/3LTJA.pdbA/Peeling/Peeling.log'},
#  {'id': 233,
#   'source': 'dataset',
#   'path': '../data/data_sword/1DVKA/PDBs_Clean/1DVKA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1DVKA/PDBs_Clean/1DVKA.pdbA/Peeling/Peeling.log'},
#  {'id': 234,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EQ2A/PDBs_Clean/1EQ2A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EQ2A/PDBs_Clean/1EQ2A.pdbA/Peeling/Peeling.log'},
#  {'id': 235,
#   'source': 'dataset',
#   'path': '../data/data_sword/2X5NA/PDBs_Clean/2X5NA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2X5NA/PDBs_Clean/2X5NA.pdbA/Peeling/Peeling.log'},
#  {'id': 236,
#   'source': 'dataset',
#   'path': '../data/data_sword/3R9TA/PDBs_Clean/3R9TA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3R9TA/PDBs_Clean/3R9TA.pdbA/Peeling/Peeling.log'},
#  {'id': 237,
#   'source': 'dataset',
#   'path': '../data/data_sword/3KBYA/PDBs_Clean/3KBYA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3KBYA/PDBs_Clean/3KBYA.pdbA/Peeling/Peeling.log'},
#  {'id': 238,
#   'source': 'dataset',
#   'path': '../data/data_sword/3NE0A/PDBs_Clean/3NE0A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3NE0A/PDBs_Clean/3NE0A.pdbA/Peeling/Peeling.log'},
#  {'id': 239,
#   'source': 'dataset',
# ...
#   'annot': '../data/data_sword/2E12A/PDBs_Clean/2E12A.pdbA/Peeling/Peeling.log'},
#  {'id': 921,
#   'source': 'dataset',
#   'path': '../data/data_sword/1VI4A/PDBs_Clean/1VI4A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1VI4A/PDBs_Clean/1VI4A.pdbA/Peeling/Peeling.log'},
#  {'id': 922,
#   'source': 'dataset',
#   'path': '../data/data_sword/1LF7A/PDBs_Clean/1LF7A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1LF7A/PDBs_Clean/1LF7A.pdbA/Peeling/Peeling.log'},
#  {'id': 923,
#   'source': 'dataset',
#   'path': '../data/data_sword/3L51B/PDBs_Clean/3L51B.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/3L51B/PDBs_Clean/3L51B.pdbB/Peeling/Peeling.log'},
#  {'id': 924,
#   'source': 'dataset',
#   'path': '../data/data_sword/2P9RA/PDBs_Clean/2P9RA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2P9RA/PDBs_Clean/2P9RA.pdbA/Peeling/Peeling.log'},
#  {'id': 925,
#   'source': 'dataset',
#   'path': '../data/data_sword/2FSWA/PDBs_Clean/2FSWA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2FSWA/PDBs_Clean/2FSWA.pdbA/Peeling/Peeling.log'},
#  {'id': 926,
#   'source': 'dataset',
#   'path': '../data/data_sword/3PBTA/PDBs_Clean/3PBTA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3PBTA/PDBs_Clean/3PBTA.pdbA/Peeling/Peeling.log'},
#  {'id': 927,
#   'source': 'dataset',
#   'path': '../data/data_sword/1BYIA/PDBs_Clean/1BYIA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1BYIA/PDBs_Clean/1BYIA.pdbA/Peeling/Peeling.log'},
#  {'id': 928,
#   'source': 'dataset',
#   'path': '../data/data_sword/1IBYA/PDBs_Clean/1IBYA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1IBYA/PDBs_Clean/1IBYA.pdbA/Peeling/Peeling.log'},
#  {'id': 929,
#   'source': 'dataset',
#   'path': '../data/data_sword/2FHQA/PDBs_Clean/2FHQA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2FHQA/PDBs_Clean/2FHQA.pdbA/Peeling/Peeling.log'},
#  {'id': 930,
#   'source': 'dataset',
#   'path': '../data/data_sword/3KE3A/PDBs_Clean/3KE3A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3KE3A/PDBs_Clean/3KE3A.pdbA/Peeling/Peeling.log'},
#  {'id': 931,
#   'source': 'dataset',
#   'path': '../data/data_sword/2E9XA/PDBs_Clean/2E9XA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2E9XA/PDBs_Clean/2E9XA.pdbA/Peeling/Peeling.log'},
#  {'id': 932,
#   'source': 'dataset',
#   'path': '../data/data_sword/3DCLA/PDBs_Clean/3DCLA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3DCLA/PDBs_Clean/3DCLA.pdbA/Peeling/Peeling.log'},
#  {'id': 933,
#   'source': 'dataset',
#   'path': '../data/data_sword/3DA5A/PDBs_Clean/3DA5A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3DA5A/PDBs_Clean/3DA5A.pdbA/Peeling/Peeling.log'},
#  {'id': 934,
#   'source': 'dataset',
#   'path': '../data/data_sword/3C8LA/PDBs_Clean/3C8LA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3C8LA/PDBs_Clean/3C8LA.pdbA/Peeling/Peeling.log'},
#  {'id': 935,
#   'source': 'dataset',
#   'path': '../data/data_sword/2FUPA/PDBs_Clean/2FUPA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2FUPA/PDBs_Clean/2FUPA.pdbA/Peeling/Peeling.log'},
#  {'id': 936,
#   'source': 'dataset',
#   'path': '../data/data_sword/3QT2A/PDBs_Clean/3QT2A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3QT2A/PDBs_Clean/3QT2A.pdbA/Peeling/Peeling.log'},
#  {'id': 937,
#   'source': 'dataset',
#   'path': '../data/data_sword/4DHXB/PDBs_Clean/4DHXB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/4DHXB/PDBs_Clean/4DHXB.pdbB/Peeling/Peeling.log'},
#  {'id': 938,
#   'source': 'dataset',
#   'path': '../data/data_sword/1QLMA/PDBs_Clean/1QLMA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1QLMA/PDBs_Clean/1QLMA.pdbA/Peeling/Peeling.log'},
#  {'id': 939,
#   'source': 'dataset',
#   'path': '../data/data_sword/1WJXA/PDBs_Clean/1WJXA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1WJXA/PDBs_Clean/1WJXA.pdbA/Peeling/Peeling.log'},
#  {'id': 940,
#   'source': 'dataset',
#   'path': '../data/data_sword/1R31A/PDBs_Clean/1R31A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1R31A/PDBs_Clean/1R31A.pdbA/Peeling/Peeling.log'},
#  {'id': 941,
#   'source': 'dataset',
#   'path': '../data/data_sword/1DBQA/PDBs_Clean/1DBQA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1DBQA/PDBs_Clean/1DBQA.pdbA/Peeling/Peeling.log'},
#  {'id': 942,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GNLA/PDBs_Clean/1GNLA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GNLA/PDBs_Clean/1GNLA.pdbA/Peeling/Peeling.log'},
#  {'id': 943,
#   'source': 'dataset',
#   'path': '../data/data_sword/3MWZA/PDBs_Clean/3MWZA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3MWZA/PDBs_Clean/3MWZA.pdbA/Peeling/Peeling.log'},
#  {'id': 944,
#   'source': 'dataset',
#   'path': '../data/data_sword/1ZXZA/PDBs_Clean/1ZXZA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1ZXZA/PDBs_Clean/1ZXZA.pdbA/Peeling/Peeling.log'},
#  {'id': 945,
#   'source': 'dataset',
#   'path': '../data/data_sword/3BBYA/PDBs_Clean/3BBYA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3BBYA/PDBs_Clean/3BBYA.pdbA/Peeling/Peeling.log'},
#  {'id': 946,
#   'source': 'dataset',
#   'path': '../data/data_sword/1PEXA/PDBs_Clean/1PEXA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1PEXA/PDBs_Clean/1PEXA.pdbA/Peeling/Peeling.log'},
#  {'id': 947,
#   'source': 'dataset',
#   'path': '../data/data_sword/2B25A/PDBs_Clean/2B25A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2B25A/PDBs_Clean/2B25A.pdbA/Peeling/Peeling.log'},
#  {'id': 948,
#   'source': 'dataset',
#   'path': '../data/data_sword/2LISA/PDBs_Clean/2LISA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2LISA/PDBs_Clean/2LISA.pdbA/Peeling/Peeling.log'},
#  {'id': 949,
#   'source': 'dataset',
#   'path': '../data/data_sword/3QOOA/PDBs_Clean/3QOOA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3QOOA/PDBs_Clean/3QOOA.pdbA/Peeling/Peeling.log'},
#  {'id': 950,
#   'source': 'dataset',
#   'path': '../data/data_sword/3H35A/PDBs_Clean/3H35A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3H35A/PDBs_Clean/3H35A.pdbA/Peeling/Peeling.log'},
#  {'id': 951,
#   'source': 'dataset',
#   'path': '../data/data_sword/2O8LA/PDBs_Clean/2O8LA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2O8LA/PDBs_Clean/2O8LA.pdbA/Peeling/Peeling.log'},
#  {'id': 952,
#   'source': 'dataset',
#   'path': '../data/data_sword/2QYFB/PDBs_Clean/2QYFB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/2QYFB/PDBs_Clean/2QYFB.pdbB/Peeling/Peeling.log'},
#  {'id': 953,
#   'source': 'dataset',
#   'path': '../data/data_sword/1V5IB/PDBs_Clean/1V5IB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/1V5IB/PDBs_Clean/1V5IB.pdbB/Peeling/Peeling.log'},
#  {'id': 954,
#   'source': 'dataset',
#   'path': '../data/data_sword/1P9YA/PDBs_Clean/1P9YA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1P9YA/PDBs_Clean/1P9YA.pdbA/Peeling/Peeling.log'},
#  {'id': 955,
#   'source': 'dataset',
#   'path': '../data/data_sword/1MBYA/PDBs_Clean/1MBYA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1MBYA/PDBs_Clean/1MBYA.pdbA/Peeling/Peeling.log'},
#  {'id': 956,
#   'source': 'dataset',
#   'path': '../data/data_sword/3OFKA/PDBs_Clean/3OFKA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3OFKA/PDBs_Clean/3OFKA.pdbA/Peeling/Peeling.log'},
#  {'id': 957,
#   'source': 'dataset',
#   'path': '../data/data_sword/1BW0A/PDBs_Clean/1BW0A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1BW0A/PDBs_Clean/1BW0A.pdbA/Peeling/Peeling.log'},
#  {'id': 958,
#   'source': 'dataset',
#   'path': '../data/data_sword/3IRSA/PDBs_Clean/3IRSA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3IRSA/PDBs_Clean/3IRSA.pdbA/Peeling/Peeling.log'},
#  {'id': 959,
#   'source': 'dataset',
#   'path': '../data/data_sword/1PWHA/PDBs_Clean/1PWHA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1PWHA/PDBs_Clean/1PWHA.pdbA/Peeling/Peeling.log'},
#  {'id': 960,
#   'source': 'dataset',
#   'path': '../data/data_sword/3BOWC/PDBs_Clean/3BOWC.pdbC/file_proba_contact.mat',
#   'annot': '../data/data_sword/3BOWC/PDBs_Clean/3BOWC.pdbC/Peeling/Peeling.log'},
#  {'id': 961,
#   'source': 'dataset',
#   'path': '../data/data_sword/2NX9A/PDBs_Clean/2NX9A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2NX9A/PDBs_Clean/2NX9A.pdbA/Peeling/Peeling.log'},
#  {'id': 962,
#   'source': 'dataset',
#   'path': '../data/data_sword/3DEWA/PDBs_Clean/3DEWA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3DEWA/PDBs_Clean/3DEWA.pdbA/Peeling/Peeling.log'},
#  {'id': 963,
#   'source': 'dataset',
#   'path': '../data/data_sword/2O38A/PDBs_Clean/2O38A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2O38A/PDBs_Clean/2O38A.pdbA/Peeling/Peeling.log'},
#  {'id': 964,
#   'source': 'dataset',
#   'path': '../data/data_sword/2Y43A/PDBs_Clean/2Y43A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2Y43A/PDBs_Clean/2Y43A.pdbA/Peeling/Peeling.log'},
#  {'id': 965,
#   'source': 'dataset',
#   'path': '../data/data_sword/2RLDA/PDBs_Clean/2RLDA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2RLDA/PDBs_Clean/2RLDA.pdbA/Peeling/Peeling.log'},
#  {'id': 966,
#   'source': 'dataset',
#   'path': '../data/data_sword/2ZXRA/PDBs_Clean/2ZXRA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2ZXRA/PDBs_Clean/2ZXRA.pdbA/Peeling/Peeling.log'},
#  {'id': 967,
#   'source': 'dataset',
#   'path': '../data/data_sword/2FR5A/PDBs_Clean/2FR5A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2FR5A/PDBs_Clean/2FR5A.pdbA/Peeling/Peeling.log'},
#  {'id': 968,
#   'source': 'dataset',
#   'path': '../data/data_sword/2J4XA/PDBs_Clean/2J4XA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2J4XA/PDBs_Clean/2J4XA.pdbA/Peeling/Peeling.log'},
#  {'id': 969,
#   'source': 'dataset',
#   'path': '../data/data_sword/3HULA/PDBs_Clean/3HULA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3HULA/PDBs_Clean/3HULA.pdbA/Peeling/Peeling.log'},
#  {'id': 970,
#   'source': 'dataset',
#   'path': '../data/data_sword/3R03A/PDBs_Clean/3R03A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3R03A/PDBs_Clean/3R03A.pdbA/Peeling/Peeling.log'},
#  {'id': 971,
#   'source': 'dataset',
#   'path': '../data/data_sword/2CX6A/PDBs_Clean/2CX6A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2CX6A/PDBs_Clean/2CX6A.pdbA/Peeling/Peeling.log'},
#  {'id': 972,
#   'source': 'dataset',
#   'path': '../data/data_sword/3S5JA/PDBs_Clean/3S5JA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3S5JA/PDBs_Clean/3S5JA.pdbA/Peeling/Peeling.log'},
#  {'id': 973,
#   'source': 'dataset',
#   'path': '../data/data_sword/4G1OA/PDBs_Clean/4G1OA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/4G1OA/PDBs_Clean/4G1OA.pdbA/Peeling/Peeling.log'},
#  {'id': 974,
#   'source': 'dataset',
#   'path': '../data/data_sword/3IQTA/PDBs_Clean/3IQTA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3IQTA/PDBs_Clean/3IQTA.pdbA/Peeling/Peeling.log'},
#  {'id': 975,
#   'source': 'dataset',
#   'path': '../data/data_sword/1DI6A/PDBs_Clean/1DI6A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1DI6A/PDBs_Clean/1DI6A.pdbA/Peeling/Peeling.log'},
#  {'id': 976,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BKYA/PDBs_Clean/2BKYA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BKYA/PDBs_Clean/2BKYA.pdbA/Peeling/Peeling.log'},
#  {'id': 977,
#   'source': 'dataset',
#   'path': '../data/data_sword/3O6QA/PDBs_Clean/3O6QA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3O6QA/PDBs_Clean/3O6QA.pdbA/Peeling/Peeling.log'},
#  {'id': 978,
#   'source': 'dataset',
#   'path': '../data/data_sword/3U5EM/PDBs_Clean/3U5EM.pdbM/file_proba_contact.mat',
#   'annot': '../data/data_sword/3U5EM/PDBs_Clean/3U5EM.pdbM/Peeling/Peeling.log'},
#  {'id': 979,
#   'source': 'dataset',
#   'path': '../data/data_sword/2QKLA/PDBs_Clean/2QKLA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2QKLA/PDBs_Clean/2QKLA.pdbA/Peeling/Peeling.log'},
#  {'id': 980,
#   'source': 'dataset',
#   'path': '../data/data_sword/1V2ZA/PDBs_Clean/1V2ZA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1V2ZA/PDBs_Clean/1V2ZA.pdbA/Peeling/Peeling.log'},
#  {'id': 981,
#   'source': 'dataset',
#   'path': '../data/data_sword/3KTDA/PDBs_Clean/3KTDA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3KTDA/PDBs_Clean/3KTDA.pdbA/Peeling/Peeling.log'},
#  {'id': 982,
#   'source': 'dataset',
#   'path': '../data/data_sword/3RUXA/PDBs_Clean/3RUXA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3RUXA/PDBs_Clean/3RUXA.pdbA/Peeling/Peeling.log'},
#  {'id': 983,
#   'source': 'dataset',
#   'path': '../data/data_sword/2WFIA/PDBs_Clean/2WFIA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2WFIA/PDBs_Clean/2WFIA.pdbA/Peeling/Peeling.log'},
#  {'id': 984,
#   'source': 'dataset',
#   'path': '../data/data_sword/2ANXA/PDBs_Clean/2ANXA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2ANXA/PDBs_Clean/2ANXA.pdbA/Peeling/Peeling.log'},
#  {'id': 985,
#   'source': 'dataset',
#   'path': '../data/data_sword/3PU6A/PDBs_Clean/3PU6A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3PU6A/PDBs_Clean/3PU6A.pdbA/Peeling/Peeling.log'},
#  {'id': 986,
#   'source': 'dataset',
#   'path': '../data/data_sword/3S8IA/PDBs_Clean/3S8IA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3S8IA/PDBs_Clean/3S8IA.pdbA/Peeling/Peeling.log'},
#  {'id': 987,
#   'source': 'dataset',
#   'path': '../data/data_sword/2R76A/PDBs_Clean/2R76A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2R76A/PDBs_Clean/2R76A.pdbA/Peeling/Peeling.log'},
#  {'id': 988,
#   'source': 'dataset',
#   'path': '../data/data_sword/3MXZA/PDBs_Clean/3MXZA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3MXZA/PDBs_Clean/3MXZA.pdbA/Peeling/Peeling.log'},
#  {'id': 989,
#   'source': 'dataset',
#   'path': '../data/data_sword/3L4CA/PDBs_Clean/3L4CA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3L4CA/PDBs_Clean/3L4CA.pdbA/Peeling/Peeling.log'},
#  {'id': 990,
#   'source': 'dataset',
#   'path': '../data/data_sword/2E50A/PDBs_Clean/2E50A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2E50A/PDBs_Clean/2E50A.pdbA/Peeling/Peeling.log'},
#  {'id': 991,
#   'source': 'dataset',
#   'path': '../data/data_sword/3I26A/PDBs_Clean/3I26A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3I26A/PDBs_Clean/3I26A.pdbA/Peeling/Peeling.log'},
#  {'id': 992,
#   'source': 'dataset',
#   'path': '../data/data_sword/3H9WA/PDBs_Clean/3H9WA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3H9WA/PDBs_Clean/3H9WA.pdbA/Peeling/Peeling.log'},
#  {'id': 993,
#   'source': 'dataset',
#   'path': '../data/data_sword/3KANA/PDBs_Clean/3KANA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3KANA/PDBs_Clean/3KANA.pdbA/Peeling/Peeling.log'},
#  {'id': 994,
#   'source': 'dataset',
#   'path': '../data/data_sword/3D8CA/PDBs_Clean/3D8CA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3D8CA/PDBs_Clean/3D8CA.pdbA/Peeling/Peeling.log'},
#  {'id': 995,
#   'source': 'dataset',
#   'path': '../data/data_sword/3P3VA/PDBs_Clean/3P3VA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3P3VA/PDBs_Clean/3P3VA.pdbA/Peeling/Peeling.log'},
#  {'id': 996,
#   'source': 'dataset',
#   'path': '../data/data_sword/2CIUA/PDBs_Clean/2CIUA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2CIUA/PDBs_Clean/2CIUA.pdbA/Peeling/Peeling.log'},
#  {'id': 997,
#   'source': 'dataset',
#   'path': '../data/data_sword/3H8KA/PDBs_Clean/3H8KA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3H8KA/PDBs_Clean/3H8KA.pdbA/Peeling/Peeling.log'},
#  {'id': 998,
#   'source': 'dataset',
#   'path': '../data/data_sword/1Y0KA/PDBs_Clean/1Y0KA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1Y0KA/PDBs_Clean/1Y0KA.pdbA/Peeling/Peeling.log'},
#  {'id': 999,
#   'source': 'dataset',
#   'path': '../data/data_sword/3EEAA/PDBs_Clean/3EEAA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/3EEAA/PDBs_Clean/3EEAA.pdbA/Peeling/Peeling.log'},
#  ...]

# %%
test_set.image_info
# Out:
# [{'id': 0,
#   'source': 'dataset',
#   'path': '../data/data_sword/1A0IA/PDBs_Clean/1A0IA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1A0IA/PDBs_Clean/1A0IA.pdbA/Peeling/Peeling.log'},
#  {'id': 1,
#   'source': 'dataset',
#   'path': '../data/data_sword/1A0TP/PDBs_Clean/1A0TP.pdbP/file_proba_contact.mat',
#   'annot': '../data/data_sword/1A0TP/PDBs_Clean/1A0TP.pdbP/Peeling/Peeling.log'},
#  {'id': 2,
#   'source': 'dataset',
#   'path': '../data/data_sword/1A12A/PDBs_Clean/1A12A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1A12A/PDBs_Clean/1A12A.pdbA/Peeling/Peeling.log'},
#  {'id': 3,
#   'source': 'dataset',
#   'path': '../data/data_sword/1A17A/PDBs_Clean/1A17A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1A17A/PDBs_Clean/1A17A.pdbA/Peeling/Peeling.log'},
#  {'id': 4,
#   'source': 'dataset',
#   'path': '../data/data_sword/1A1IA/PDBs_Clean/1A1IA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1A1IA/PDBs_Clean/1A1IA.pdbA/Peeling/Peeling.log'},
#  {'id': 5,
#   'source': 'dataset',
#   'path': '../data/data_sword/1A1XA/PDBs_Clean/1A1XA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1A1XA/PDBs_Clean/1A1XA.pdbA/Peeling/Peeling.log'},
#  {'id': 6,
#   'source': 'dataset',
#   'path': '../data/data_sword/1A2PA/PDBs_Clean/1A2PA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1A2PA/PDBs_Clean/1A2PA.pdbA/Peeling/Peeling.log'},
#  {'id': 7,
#   'source': 'dataset',
#   'path': '../data/data_sword/1A32A/PDBs_Clean/1A32A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1A32A/PDBs_Clean/1A32A.pdbA/Peeling/Peeling.log'},
#  {'id': 8,
#   'source': 'dataset',
#   'path': '../data/data_sword/1A4PA/PDBs_Clean/1A4PA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1A4PA/PDBs_Clean/1A4PA.pdbA/Peeling/Peeling.log'},
#  {'id': 9,
#   'source': 'dataset',
#   'path': '../data/data_sword/1A6JA/PDBs_Clean/1A6JA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1A6JA/PDBs_Clean/1A6JA.pdbA/Peeling/Peeling.log'},
#  {'id': 10,
#   'source': 'dataset',
#   'path': '../data/data_sword/1A8DA/PDBs_Clean/1A8DA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1A8DA/PDBs_Clean/1A8DA.pdbA/Peeling/Peeling.log'},
#  {'id': 11,
#   'source': 'dataset',
#   'path': '../data/data_sword/1A9NA/PDBs_Clean/1A9NA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1A9NA/PDBs_Clean/1A9NA.pdbA/Peeling/Peeling.log'},
#  {'id': 12,
#   'source': 'dataset',
#   'path': '../data/data_sword/1AF7A/PDBs_Clean/1AF7A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1AF7A/PDBs_Clean/1AF7A.pdbA/Peeling/Peeling.log'},
#  {'id': 13,
#   'source': 'dataset',
#   'path': '../data/data_sword/1AGQA/PDBs_Clean/1AGQA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1AGQA/PDBs_Clean/1AGQA.pdbA/Peeling/Peeling.log'},
#  {'id': 14,
#   'source': 'dataset',
#   'path': '../data/data_sword/1AHSA/PDBs_Clean/1AHSA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1AHSA/PDBs_Clean/1AHSA.pdbA/Peeling/Peeling.log'},
#  {'id': 15,
#   'source': 'dataset',
#   'path': '../data/data_sword/1AIHA/PDBs_Clean/1AIHA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1AIHA/PDBs_Clean/1AIHA.pdbA/Peeling/Peeling.log'},
#  {'id': 16,
#   'source': 'dataset',
#   'path': '../data/data_sword/1AK0A/PDBs_Clean/1AK0A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1AK0A/PDBs_Clean/1AK0A.pdbA/Peeling/Peeling.log'},
#  {'id': 17,
#   'source': 'dataset',
#   'path': '../data/data_sword/1AMUA/PDBs_Clean/1AMUA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1AMUA/PDBs_Clean/1AMUA.pdbA/Peeling/Peeling.log'},
#  {'id': 18,
#   'source': 'dataset',
#   'path': '../data/data_sword/1AOPA/PDBs_Clean/1AOPA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1AOPA/PDBs_Clean/1AOPA.pdbA/Peeling/Peeling.log'},
#  {'id': 19,
#   'source': 'dataset',
#   'path': '../data/data_sword/1AUKA/PDBs_Clean/1AUKA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1AUKA/PDBs_Clean/1AUKA.pdbA/Peeling/Peeling.log'},
#  {'id': 20,
#   'source': 'dataset',
#   'path': '../data/data_sword/1AVGI/PDBs_Clean/1AVGI.pdbI/file_proba_contact.mat',
#   'annot': '../data/data_sword/1AVGI/PDBs_Clean/1AVGI.pdbI/Peeling/Peeling.log'},
#  {'id': 21,
#   'source': 'dataset',
#   'path': '../data/data_sword/1AVOB/PDBs_Clean/1AVOB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/1AVOB/PDBs_Clean/1AVOB.pdbB/Peeling/Peeling.log'},
#  {'id': 22,
#   'source': 'dataset',
#   'path': '../data/data_sword/1AXDA/PDBs_Clean/1AXDA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1AXDA/PDBs_Clean/1AXDA.pdbA/Peeling/Peeling.log'},
#  {'id': 23,
#   'source': 'dataset',
#   'path': '../data/data_sword/1AYOA/PDBs_Clean/1AYOA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1AYOA/PDBs_Clean/1AYOA.pdbA/Peeling/Peeling.log'},
#  {'id': 24,
#   'source': 'dataset',
#   'path': '../data/data_sword/1B34A/PDBs_Clean/1B34A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1B34A/PDBs_Clean/1B34A.pdbA/Peeling/Peeling.log'},
#  {'id': 25,
#   'source': 'dataset',
#   'path': '../data/data_sword/1B67A/PDBs_Clean/1B67A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1B67A/PDBs_Clean/1B67A.pdbA/Peeling/Peeling.log'},
#  {'id': 26,
#   'source': 'dataset',
#   'path': '../data/data_sword/1B77A/PDBs_Clean/1B77A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1B77A/PDBs_Clean/1B77A.pdbA/Peeling/Peeling.log'},
#  {'id': 27,
#   'source': 'dataset',
#   'path': '../data/data_sword/1B9HA/PDBs_Clean/1B9HA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1B9HA/PDBs_Clean/1B9HA.pdbA/Peeling/Peeling.log'},
#  {'id': 28,
#   'source': 'dataset',
#   'path': '../data/data_sword/1B9LA/PDBs_Clean/1B9LA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1B9LA/PDBs_Clean/1B9LA.pdbA/Peeling/Peeling.log'},
#  {'id': 29,
#   'source': 'dataset',
#   'path': '../data/data_sword/1B9OA/PDBs_Clean/1B9OA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1B9OA/PDBs_Clean/1B9OA.pdbA/Peeling/Peeling.log'},
#  {'id': 30,
#   'source': 'dataset',
#   'path': '../data/data_sword/1B9WA/PDBs_Clean/1B9WA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1B9WA/PDBs_Clean/1B9WA.pdbA/Peeling/Peeling.log'},
#  {'id': 31,
#   'source': 'dataset',
#   'path': '../data/data_sword/1BCPD/PDBs_Clean/1BCPD.pdbD/file_proba_contact.mat',
#   'annot': '../data/data_sword/1BCPD/PDBs_Clean/1BCPD.pdbD/Peeling/Peeling.log'},
#  {'id': 32,
#   'source': 'dataset',
#   'path': '../data/data_sword/1BEBA/PDBs_Clean/1BEBA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1BEBA/PDBs_Clean/1BEBA.pdbA/Peeling/Peeling.log'},
#  {'id': 33,
#   'source': 'dataset',
#   'path': '../data/data_sword/1BG1A/PDBs_Clean/1BG1A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1BG1A/PDBs_Clean/1BG1A.pdbA/Peeling/Peeling.log'},
#  {'id': 34,
#   'source': 'dataset',
#   'path': '../data/data_sword/1BH9B/PDBs_Clean/1BH9B.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/1BH9B/PDBs_Clean/1BH9B.pdbB/Peeling/Peeling.log'},
#  {'id': 35,
#   'source': 'dataset',
#   'path': '../data/data_sword/1BJ7A/PDBs_Clean/1BJ7A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1BJ7A/PDBs_Clean/1BJ7A.pdbA/Peeling/Peeling.log'},
#  {'id': 36,
#   'source': 'dataset',
#   'path': '../data/data_sword/1BOBA/PDBs_Clean/1BOBA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1BOBA/PDBs_Clean/1BOBA.pdbA/Peeling/Peeling.log'},
#  {'id': 37,
#   'source': 'dataset',
#   'path': '../data/data_sword/1BQUA/PDBs_Clean/1BQUA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1BQUA/PDBs_Clean/1BQUA.pdbA/Peeling/Peeling.log'},
#  {'id': 38,
#   'source': 'dataset',
#   'path': '../data/data_sword/1BS0A/PDBs_Clean/1BS0A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1BS0A/PDBs_Clean/1BS0A.pdbA/Peeling/Peeling.log'},
#  {'id': 39,
#   'source': 'dataset',
#   'path': '../data/data_sword/1BTEA/PDBs_Clean/1BTEA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1BTEA/PDBs_Clean/1BTEA.pdbA/Peeling/Peeling.log'},
#  {'id': 40,
#   'source': 'dataset',
#   'path': '../data/data_sword/1BTKA/PDBs_Clean/1BTKA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1BTKA/PDBs_Clean/1BTKA.pdbA/Peeling/Peeling.log'},
#  {'id': 41,
#   'source': 'dataset',
#   'path': '../data/data_sword/1BUOA/PDBs_Clean/1BUOA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1BUOA/PDBs_Clean/1BUOA.pdbA/Peeling/Peeling.log'},
#  {'id': 42,
#   'source': 'dataset',
#   'path': '../data/data_sword/1BYRA/PDBs_Clean/1BYRA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1BYRA/PDBs_Clean/1BYRA.pdbA/Peeling/Peeling.log'},
#  {'id': 43,
#   'source': 'dataset',
#   'path': '../data/data_sword/1C4ZA/PDBs_Clean/1C4ZA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1C4ZA/PDBs_Clean/1C4ZA.pdbA/Peeling/Peeling.log'},
#  {'id': 44,
#   'source': 'dataset',
#   'path': '../data/data_sword/1C7KA/PDBs_Clean/1C7KA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1C7KA/PDBs_Clean/1C7KA.pdbA/Peeling/Peeling.log'},
#  {'id': 45,
#   'source': 'dataset',
#   'path': '../data/data_sword/1C8UA/PDBs_Clean/1C8UA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1C8UA/PDBs_Clean/1C8UA.pdbA/Peeling/Peeling.log'},
#  {'id': 46,
#   'source': 'dataset',
#   'path': '../data/data_sword/1CF7A/PDBs_Clean/1CF7A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1CF7A/PDBs_Clean/1CF7A.pdbA/Peeling/Peeling.log'},
#  {'id': 47,
#   'source': 'dataset',
#   'path': '../data/data_sword/1CF7B/PDBs_Clean/1CF7B.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/1CF7B/PDBs_Clean/1CF7B.pdbB/Peeling/Peeling.log'},
#  {'id': 48,
#   'source': 'dataset',
#   'path': '../data/data_sword/1CKTA/PDBs_Clean/1CKTA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1CKTA/PDBs_Clean/1CKTA.pdbA/Peeling/Peeling.log'},
#  {'id': 49,
#   'source': 'dataset',
#   'path': '../data/data_sword/1CMCA/PDBs_Clean/1CMCA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1CMCA/PDBs_Clean/1CMCA.pdbA/Peeling/Peeling.log'},
#  {'id': 50,
#   'source': 'dataset',
#   'path': '../data/data_sword/1CMXA/PDBs_Clean/1CMXA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1CMXA/PDBs_Clean/1CMXA.pdbA/Peeling/Peeling.log'},
#  {'id': 51,
#   'source': 'dataset',
#   'path': '../data/data_sword/1COJA/PDBs_Clean/1COJA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1COJA/PDBs_Clean/1COJA.pdbA/Peeling/Peeling.log'},
#  {'id': 52,
#   'source': 'dataset',
#   'path': '../data/data_sword/1COZA/PDBs_Clean/1COZA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1COZA/PDBs_Clean/1COZA.pdbA/Peeling/Peeling.log'},
#  {'id': 53,
#   'source': 'dataset',
#   'path': '../data/data_sword/1CQXA/PDBs_Clean/1CQXA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1CQXA/PDBs_Clean/1CQXA.pdbA/Peeling/Peeling.log'},
#  {'id': 54,
#   'source': 'dataset',
#   'path': '../data/data_sword/1CR5A/PDBs_Clean/1CR5A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1CR5A/PDBs_Clean/1CR5A.pdbA/Peeling/Peeling.log'},
#  {'id': 55,
#   'source': 'dataset',
#   'path': '../data/data_sword/1CS1A/PDBs_Clean/1CS1A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1CS1A/PDBs_Clean/1CS1A.pdbA/Peeling/Peeling.log'},
#  {'id': 56,
#   'source': 'dataset',
#   'path': '../data/data_sword/1CS6A/PDBs_Clean/1CS6A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1CS6A/PDBs_Clean/1CS6A.pdbA/Peeling/Peeling.log'},
#  {'id': 57,
#   'source': 'dataset',
#   'path': '../data/data_sword/1CSEI/PDBs_Clean/1CSEI.pdbI/file_proba_contact.mat',
#   'annot': '../data/data_sword/1CSEI/PDBs_Clean/1CSEI.pdbI/Peeling/Peeling.log'},
#  {'id': 58,
#   'source': 'dataset',
#   'path': '../data/data_sword/1CT5A/PDBs_Clean/1CT5A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1CT5A/PDBs_Clean/1CT5A.pdbA/Peeling/Peeling.log'},
#  {'id': 59,
#   'source': 'dataset',
#   'path': '../data/data_sword/1CTFA/PDBs_Clean/1CTFA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1CTFA/PDBs_Clean/1CTFA.pdbA/Peeling/Peeling.log'},
#  {'id': 60,
#   'source': 'dataset',
#   'path': '../data/data_sword/1CTJA/PDBs_Clean/1CTJA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1CTJA/PDBs_Clean/1CTJA.pdbA/Peeling/Peeling.log'},
#  {'id': 61,
#   'source': 'dataset',
#   'path': '../data/data_sword/1CVRA/PDBs_Clean/1CVRA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1CVRA/PDBs_Clean/1CVRA.pdbA/Peeling/Peeling.log'},
#  {'id': 62,
#   'source': 'dataset',
#   'path': '../data/data_sword/1CYXA/PDBs_Clean/1CYXA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1CYXA/PDBs_Clean/1CYXA.pdbA/Peeling/Peeling.log'},
#  {'id': 63,
#   'source': 'dataset',
#   'path': '../data/data_sword/1CZJA/PDBs_Clean/1CZJA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1CZJA/PDBs_Clean/1CZJA.pdbA/Peeling/Peeling.log'},
#  {'id': 64,
#   'source': 'dataset',
#   'path': '../data/data_sword/1CZYA/PDBs_Clean/1CZYA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1CZYA/PDBs_Clean/1CZYA.pdbA/Peeling/Peeling.log'},
#  {'id': 65,
#   'source': 'dataset',
#   'path': '../data/data_sword/1D02A/PDBs_Clean/1D02A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1D02A/PDBs_Clean/1D02A.pdbA/Peeling/Peeling.log'},
#  {'id': 66,
#   'source': 'dataset',
#   'path': '../data/data_sword/1D2SA/PDBs_Clean/1D2SA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1D2SA/PDBs_Clean/1D2SA.pdbA/Peeling/Peeling.log'},
#  {'id': 67,
#   'source': 'dataset',
#   'path': '../data/data_sword/1D2ZB/PDBs_Clean/1D2ZB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/1D2ZB/PDBs_Clean/1D2ZB.pdbB/Peeling/Peeling.log'},
#  {'id': 68,
#   'source': 'dataset',
#   'path': '../data/data_sword/1D3BA/PDBs_Clean/1D3BA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1D3BA/PDBs_Clean/1D3BA.pdbA/Peeling/Peeling.log'},
#  {'id': 69,
#   'source': 'dataset',
#   'path': '../data/data_sword/1D3BB/PDBs_Clean/1D3BB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/1D3BB/PDBs_Clean/1D3BB.pdbB/Peeling/Peeling.log'},
#  {'id': 70,
#   'source': 'dataset',
#   'path': '../data/data_sword/1D3YA/PDBs_Clean/1D3YA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1D3YA/PDBs_Clean/1D3YA.pdbA/Peeling/Peeling.log'},
#  {'id': 71,
#   'source': 'dataset',
#   'path': '../data/data_sword/1D7OA/PDBs_Clean/1D7OA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1D7OA/PDBs_Clean/1D7OA.pdbA/Peeling/Peeling.log'},
#  {'id': 72,
#   'source': 'dataset',
#   'path': '../data/data_sword/1D8HA/PDBs_Clean/1D8HA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1D8HA/PDBs_Clean/1D8HA.pdbA/Peeling/Peeling.log'},
#  {'id': 73,
#   'source': 'dataset',
#   'path': '../data/data_sword/1D9CA/PDBs_Clean/1D9CA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1D9CA/PDBs_Clean/1D9CA.pdbA/Peeling/Peeling.log'},
#  {'id': 74,
#   'source': 'dataset',
#   'path': '../data/data_sword/1DCFA/PDBs_Clean/1DCFA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1DCFA/PDBs_Clean/1DCFA.pdbA/Peeling/Peeling.log'},
#  {'id': 75,
#   'source': 'dataset',
#   'path': '../data/data_sword/1DFMA/PDBs_Clean/1DFMA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1DFMA/PDBs_Clean/1DFMA.pdbA/Peeling/Peeling.log'},
#  {'id': 76,
#   'source': 'dataset',
#   'path': '../data/data_sword/1DFUP/PDBs_Clean/1DFUP.pdbP/file_proba_contact.mat',
#   'annot': '../data/data_sword/1DFUP/PDBs_Clean/1DFUP.pdbP/Peeling/Peeling.log'},
#  {'id': 77,
#   'source': 'dataset',
#   'path': '../data/data_sword/1DG6A/PDBs_Clean/1DG6A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1DG6A/PDBs_Clean/1DG6A.pdbA/Peeling/Peeling.log'},
#  {'id': 78,
#   'source': 'dataset',
#   'path': '../data/data_sword/1DGWA/PDBs_Clean/1DGWA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1DGWA/PDBs_Clean/1DGWA.pdbA/Peeling/Peeling.log'},
#  {'id': 79,
#   'source': 'dataset',
#   'path': '../data/data_sword/1DGWX/PDBs_Clean/1DGWX.pdbX/file_proba_contact.mat',
#   'annot': '../data/data_sword/1DGWX/PDBs_Clean/1DGWX.pdbX/Peeling/Peeling.log'},
#  {'id': 80,
#   'source': 'dataset',
#   'path': '../data/data_sword/1DGWY/PDBs_Clean/1DGWY.pdbY/file_proba_contact.mat',
#   'annot': '../data/data_sword/1DGWY/PDBs_Clean/1DGWY.pdbY/Peeling/Peeling.log'},
#  {'id': 81,
#   'source': 'dataset',
#   'path': '../data/data_sword/1DKQA/PDBs_Clean/1DKQA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1DKQA/PDBs_Clean/1DKQA.pdbA/Peeling/Peeling.log'},
#  {'id': 82,
#   'source': 'dataset',
#   'path': '../data/data_sword/1DLWA/PDBs_Clean/1DLWA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1DLWA/PDBs_Clean/1DLWA.pdbA/Peeling/Peeling.log'},
#  {'id': 83,
#   'source': 'dataset',
#   'path': '../data/data_sword/1DP4A/PDBs_Clean/1DP4A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1DP4A/PDBs_Clean/1DP4A.pdbA/Peeling/Peeling.log'},
#  {'id': 84,
#   'source': 'dataset',
#   'path': '../data/data_sword/1DTDB/PDBs_Clean/1DTDB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/1DTDB/PDBs_Clean/1DTDB.pdbB/Peeling/Peeling.log'},
#  {'id': 85,
#   'source': 'dataset',
#   'path': '../data/data_sword/1DVOA/PDBs_Clean/1DVOA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1DVOA/PDBs_Clean/1DVOA.pdbA/Peeling/Peeling.log'},
#  {'id': 86,
#   'source': 'dataset',
#   'path': '../data/data_sword/1DX5I/PDBs_Clean/1DX5I.pdbI/file_proba_contact.mat',
#   'annot': '../data/data_sword/1DX5I/PDBs_Clean/1DX5I.pdbI/Peeling/Peeling.log'},
#  {'id': 87,
#   'source': 'dataset',
#   'path': '../data/data_sword/1DXYA/PDBs_Clean/1DXYA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1DXYA/PDBs_Clean/1DXYA.pdbA/Peeling/Peeling.log'},
#  {'id': 88,
#   'source': 'dataset',
#   'path': '../data/data_sword/1DYOA/PDBs_Clean/1DYOA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1DYOA/PDBs_Clean/1DYOA.pdbA/Peeling/Peeling.log'},
#  {'id': 89,
#   'source': 'dataset',
#   'path': '../data/data_sword/1DZKA/PDBs_Clean/1DZKA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1DZKA/PDBs_Clean/1DZKA.pdbA/Peeling/Peeling.log'},
#  {'id': 90,
#   'source': 'dataset',
#   'path': '../data/data_sword/1E29A/PDBs_Clean/1E29A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1E29A/PDBs_Clean/1E29A.pdbA/Peeling/Peeling.log'},
#  {'id': 91,
#   'source': 'dataset',
#   'path': '../data/data_sword/1E2KA/PDBs_Clean/1E2KA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1E2KA/PDBs_Clean/1E2KA.pdbA/Peeling/Peeling.log'},
#  {'id': 92,
#   'source': 'dataset',
#   'path': '../data/data_sword/1E3OC/PDBs_Clean/1E3OC.pdbC/file_proba_contact.mat',
#   'annot': '../data/data_sword/1E3OC/PDBs_Clean/1E3OC.pdbC/Peeling/Peeling.log'},
#  {'id': 93,
#   'source': 'dataset',
#   'path': '../data/data_sword/1E58A/PDBs_Clean/1E58A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1E58A/PDBs_Clean/1E58A.pdbA/Peeling/Peeling.log'},
#  {'id': 94,
#   'source': 'dataset',
#   'path': '../data/data_sword/1E8YA/PDBs_Clean/1E8YA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1E8YA/PDBs_Clean/1E8YA.pdbA/Peeling/Peeling.log'},
#  {'id': 95,
#   'source': 'dataset',
#   'path': '../data/data_sword/1E9GA/PDBs_Clean/1E9GA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1E9GA/PDBs_Clean/1E9GA.pdbA/Peeling/Peeling.log'},
#  {'id': 96,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EAQA/PDBs_Clean/1EAQA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EAQA/PDBs_Clean/1EAQA.pdbA/Peeling/Peeling.log'},
#  {'id': 97,
#   'source': 'dataset',
#   'path': '../data/data_sword/1ECFA/PDBs_Clean/1ECFA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1ECFA/PDBs_Clean/1ECFA.pdbA/Peeling/Peeling.log'},
#  {'id': 98,
#   'source': 'dataset',
#   'path': '../data/data_sword/1ECSA/PDBs_Clean/1ECSA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1ECSA/PDBs_Clean/1ECSA.pdbA/Peeling/Peeling.log'},
#  {'id': 99,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EEXB/PDBs_Clean/1EEXB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EEXB/PDBs_Clean/1EEXB.pdbB/Peeling/Peeling.log'},
#  {'id': 100,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EEXG/PDBs_Clean/1EEXG.pdbG/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EEXG/PDBs_Clean/1EEXG.pdbG/Peeling/Peeling.log'},
#  {'id': 101,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EFYA/PDBs_Clean/1EFYA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EFYA/PDBs_Clean/1EFYA.pdbA/Peeling/Peeling.log'},
#  {'id': 102,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EG2A/PDBs_Clean/1EG2A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EG2A/PDBs_Clean/1EG2A.pdbA/Peeling/Peeling.log'},
#  {'id': 103,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EG3A/PDBs_Clean/1EG3A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EG3A/PDBs_Clean/1EG3A.pdbA/Peeling/Peeling.log'},
#  {'id': 104,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EJFA/PDBs_Clean/1EJFA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EJFA/PDBs_Clean/1EJFA.pdbA/Peeling/Peeling.log'},
#  {'id': 105,
#   'source': 'dataset',
#   'path': '../data/data_sword/1ELKA/PDBs_Clean/1ELKA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1ELKA/PDBs_Clean/1ELKA.pdbA/Peeling/Peeling.log'},
#  {'id': 106,
#   'source': 'dataset',
#   'path': '../data/data_sword/1ELUA/PDBs_Clean/1ELUA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1ELUA/PDBs_Clean/1ELUA.pdbA/Peeling/Peeling.log'},
#  {'id': 107,
#   'source': 'dataset',
#   'path': '../data/data_sword/1ELVA/PDBs_Clean/1ELVA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1ELVA/PDBs_Clean/1ELVA.pdbA/Peeling/Peeling.log'},
#  {'id': 108,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EP0A/PDBs_Clean/1EP0A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EP0A/PDBs_Clean/1EP0A.pdbA/Peeling/Peeling.log'},
#  {'id': 109,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EP3B/PDBs_Clean/1EP3B.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EP3B/PDBs_Clean/1EP3B.pdbB/Peeling/Peeling.log'},
#  {'id': 110,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EPAA/PDBs_Clean/1EPAA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EPAA/PDBs_Clean/1EPAA.pdbA/Peeling/Peeling.log'},
#  {'id': 111,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EPUA/PDBs_Clean/1EPUA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EPUA/PDBs_Clean/1EPUA.pdbA/Peeling/Peeling.log'},
#  {'id': 112,
#   'source': 'dataset',
#   'path': '../data/data_sword/1ET9A/PDBs_Clean/1ET9A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1ET9A/PDBs_Clean/1ET9A.pdbA/Peeling/Peeling.log'},
#  {'id': 113,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EUVA/PDBs_Clean/1EUVA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EUVA/PDBs_Clean/1EUVA.pdbA/Peeling/Peeling.log'},
#  {'id': 114,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EVHA/PDBs_Clean/1EVHA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EVHA/PDBs_Clean/1EVHA.pdbA/Peeling/Peeling.log'},
#  {'id': 115,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EVYA/PDBs_Clean/1EVYA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EVYA/PDBs_Clean/1EVYA.pdbA/Peeling/Peeling.log'},
#  {'id': 116,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EXTA/PDBs_Clean/1EXTA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EXTA/PDBs_Clean/1EXTA.pdbA/Peeling/Peeling.log'},
#  {'id': 117,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EZ0A/PDBs_Clean/1EZ0A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EZ0A/PDBs_Clean/1EZ0A.pdbA/Peeling/Peeling.log'},
#  {'id': 118,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EZ4A/PDBs_Clean/1EZ4A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EZ4A/PDBs_Clean/1EZ4A.pdbA/Peeling/Peeling.log'},
#  {'id': 119,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EZGA/PDBs_Clean/1EZGA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EZGA/PDBs_Clean/1EZGA.pdbA/Peeling/Peeling.log'},
#  {'id': 120,
#   'source': 'dataset',
#   'path': '../data/data_sword/1EZJA/PDBs_Clean/1EZJA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1EZJA/PDBs_Clean/1EZJA.pdbA/Peeling/Peeling.log'},
#  {'id': 121,
#   'source': 'dataset',
#   'path': '../data/data_sword/1F08A/PDBs_Clean/1F08A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1F08A/PDBs_Clean/1F08A.pdbA/Peeling/Peeling.log'},
#  {'id': 122,
#   'source': 'dataset',
#   'path': '../data/data_sword/1F1UA/PDBs_Clean/1F1UA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1F1UA/PDBs_Clean/1F1UA.pdbA/Peeling/Peeling.log'},
#  {'id': 123,
#   'source': 'dataset',
#   'path': '../data/data_sword/1F2LA/PDBs_Clean/1F2LA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1F2LA/PDBs_Clean/1F2LA.pdbA/Peeling/Peeling.log'},
#  {'id': 124,
#   'source': 'dataset',
#   'path': '../data/data_sword/1F32A/PDBs_Clean/1F32A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1F32A/PDBs_Clean/1F32A.pdbA/Peeling/Peeling.log'},
#  {'id': 125,
#   'source': 'dataset',
#   'path': '../data/data_sword/1F4PA/PDBs_Clean/1F4PA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1F4PA/PDBs_Clean/1F4PA.pdbA/Peeling/Peeling.log'},
#  {'id': 126,
#   'source': 'dataset',
#   'path': '../data/data_sword/1F6BA/PDBs_Clean/1F6BA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1F6BA/PDBs_Clean/1F6BA.pdbA/Peeling/Peeling.log'},
#  {'id': 127,
#   'source': 'dataset',
#   'path': '../data/data_sword/1F7DA/PDBs_Clean/1F7DA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1F7DA/PDBs_Clean/1F7DA.pdbA/Peeling/Peeling.log'},
#  {'id': 128,
#   'source': 'dataset',
#   'path': '../data/data_sword/1F7SA/PDBs_Clean/1F7SA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1F7SA/PDBs_Clean/1F7SA.pdbA/Peeling/Peeling.log'},
#  {'id': 129,
#   'source': 'dataset',
#   'path': '../data/data_sword/1F86A/PDBs_Clean/1F86A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1F86A/PDBs_Clean/1F86A.pdbA/Peeling/Peeling.log'},
#  {'id': 130,
#   'source': 'dataset',
#   'path': '../data/data_sword/1F97A/PDBs_Clean/1F97A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1F97A/PDBs_Clean/1F97A.pdbA/Peeling/Peeling.log'},
#  {'id': 131,
#   'source': 'dataset',
#   'path': '../data/data_sword/1F9ZA/PDBs_Clean/1F9ZA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1F9ZA/PDBs_Clean/1F9ZA.pdbA/Peeling/Peeling.log'},
#  {'id': 132,
#   'source': 'dataset',
#   'path': '../data/data_sword/1FAOA/PDBs_Clean/1FAOA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1FAOA/PDBs_Clean/1FAOA.pdbA/Peeling/Peeling.log'},
#  {'id': 133,
#   'source': 'dataset',
#   'path': '../data/data_sword/1FD9A/PDBs_Clean/1FD9A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1FD9A/PDBs_Clean/1FD9A.pdbA/Peeling/Peeling.log'},
#  {'id': 134,
#   'source': 'dataset',
#   'path': '../data/data_sword/1FEPA/PDBs_Clean/1FEPA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1FEPA/PDBs_Clean/1FEPA.pdbA/Peeling/Peeling.log'},
#  {'id': 135,
#   'source': 'dataset',
#   'path': '../data/data_sword/1FL0A/PDBs_Clean/1FL0A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1FL0A/PDBs_Clean/1FL0A.pdbA/Peeling/Peeling.log'},
#  {'id': 136,
#   'source': 'dataset',
#   'path': '../data/data_sword/1FO0B/PDBs_Clean/1FO0B.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/1FO0B/PDBs_Clean/1FO0B.pdbB/Peeling/Peeling.log'},
#  {'id': 137,
#   'source': 'dataset',
#   'path': '../data/data_sword/1FP2A/PDBs_Clean/1FP2A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1FP2A/PDBs_Clean/1FP2A.pdbA/Peeling/Peeling.log'},
#  {'id': 138,
#   'source': 'dataset',
#   'path': '../data/data_sword/1FP3A/PDBs_Clean/1FP3A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1FP3A/PDBs_Clean/1FP3A.pdbA/Peeling/Peeling.log'},
#  {'id': 139,
#   'source': 'dataset',
#   'path': '../data/data_sword/1FSUA/PDBs_Clean/1FSUA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1FSUA/PDBs_Clean/1FSUA.pdbA/Peeling/Peeling.log'},
#  {'id': 140,
#   'source': 'dataset',
#   'path': '../data/data_sword/1FYXA/PDBs_Clean/1FYXA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1FYXA/PDBs_Clean/1FYXA.pdbA/Peeling/Peeling.log'},
#  {'id': 141,
#   'source': 'dataset',
#   'path': '../data/data_sword/1G0UD/PDBs_Clean/1G0UD.pdbD/file_proba_contact.mat',
#   'annot': '../data/data_sword/1G0UD/PDBs_Clean/1G0UD.pdbD/Peeling/Peeling.log'},
#  {'id': 142,
#   'source': 'dataset',
#   'path': '../data/data_sword/1G2QA/PDBs_Clean/1G2QA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1G2QA/PDBs_Clean/1G2QA.pdbA/Peeling/Peeling.log'},
#  {'id': 143,
#   'source': 'dataset',
#   'path': '../data/data_sword/1G3NC/PDBs_Clean/1G3NC.pdbC/file_proba_contact.mat',
#   'annot': '../data/data_sword/1G3NC/PDBs_Clean/1G3NC.pdbC/Peeling/Peeling.log'},
#  {'id': 144,
#   'source': 'dataset',
#   'path': '../data/data_sword/1G3PA/PDBs_Clean/1G3PA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1G3PA/PDBs_Clean/1G3PA.pdbA/Peeling/Peeling.log'},
#  {'id': 145,
#   'source': 'dataset',
#   'path': '../data/data_sword/1G4YB/PDBs_Clean/1G4YB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/1G4YB/PDBs_Clean/1G4YB.pdbB/Peeling/Peeling.log'},
#  {'id': 146,
#   'source': 'dataset',
#   'path': '../data/data_sword/1G8KA/PDBs_Clean/1G8KA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1G8KA/PDBs_Clean/1G8KA.pdbA/Peeling/Peeling.log'},
#  {'id': 147,
#   'source': 'dataset',
#   'path': '../data/data_sword/1G8LA/PDBs_Clean/1G8LA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1G8LA/PDBs_Clean/1G8LA.pdbA/Peeling/Peeling.log'},
#  {'id': 148,
#   'source': 'dataset',
#   'path': '../data/data_sword/1G8QA/PDBs_Clean/1G8QA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1G8QA/PDBs_Clean/1G8QA.pdbA/Peeling/Peeling.log'},
#  {'id': 149,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GCYA/PDBs_Clean/1GCYA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GCYA/PDBs_Clean/1GCYA.pdbA/Peeling/Peeling.log'},
#  {'id': 150,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GD8A/PDBs_Clean/1GD8A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GD8A/PDBs_Clean/1GD8A.pdbA/Peeling/Peeling.log'},
#  {'id': 151,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GEGA/PDBs_Clean/1GEGA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GEGA/PDBs_Clean/1GEGA.pdbA/Peeling/Peeling.log'},
#  {'id': 152,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GGPB/PDBs_Clean/1GGPB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GGPB/PDBs_Clean/1GGPB.pdbB/Peeling/Peeling.log'},
#  {'id': 153,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GHPA/PDBs_Clean/1GHPA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GHPA/PDBs_Clean/1GHPA.pdbA/Peeling/Peeling.log'},
#  {'id': 154,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GKMA/PDBs_Clean/1GKMA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GKMA/PDBs_Clean/1GKMA.pdbA/Peeling/Peeling.log'},
#  {'id': 155,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GKRA/PDBs_Clean/1GKRA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GKRA/PDBs_Clean/1GKRA.pdbA/Peeling/Peeling.log'},
#  {'id': 156,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GL4A/PDBs_Clean/1GL4A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GL4A/PDBs_Clean/1GL4A.pdbA/Peeling/Peeling.log'},
#  {'id': 157,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GNWA/PDBs_Clean/1GNWA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GNWA/PDBs_Clean/1GNWA.pdbA/Peeling/Peeling.log'},
#  {'id': 158,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GSAA/PDBs_Clean/1GSAA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GSAA/PDBs_Clean/1GSAA.pdbA/Peeling/Peeling.log'},
#  {'id': 159,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GSMA/PDBs_Clean/1GSMA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GSMA/PDBs_Clean/1GSMA.pdbA/Peeling/Peeling.log'},
#  {'id': 160,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GTDA/PDBs_Clean/1GTDA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GTDA/PDBs_Clean/1GTDA.pdbA/Peeling/Peeling.log'},
#  {'id': 161,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GTTA/PDBs_Clean/1GTTA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GTTA/PDBs_Clean/1GTTA.pdbA/Peeling/Peeling.log'},
#  {'id': 162,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GTVA/PDBs_Clean/1GTVA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GTVA/PDBs_Clean/1GTVA.pdbA/Peeling/Peeling.log'},
#  {'id': 163,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GU2A/PDBs_Clean/1GU2A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GU2A/PDBs_Clean/1GU2A.pdbA/Peeling/Peeling.log'},
#  {'id': 164,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GU4A/PDBs_Clean/1GU4A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GU4A/PDBs_Clean/1GU4A.pdbA/Peeling/Peeling.log'},
#  {'id': 165,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GU7A/PDBs_Clean/1GU7A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GU7A/PDBs_Clean/1GU7A.pdbA/Peeling/Peeling.log'},
#  {'id': 166,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GUTA/PDBs_Clean/1GUTA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GUTA/PDBs_Clean/1GUTA.pdbA/Peeling/Peeling.log'},
#  {'id': 167,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GV9A/PDBs_Clean/1GV9A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GV9A/PDBs_Clean/1GV9A.pdbA/Peeling/Peeling.log'},
#  {'id': 168,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GWEA/PDBs_Clean/1GWEA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GWEA/PDBs_Clean/1GWEA.pdbA/Peeling/Peeling.log'},
#  {'id': 169,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GWYA/PDBs_Clean/1GWYA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GWYA/PDBs_Clean/1GWYA.pdbA/Peeling/Peeling.log'},
#  {'id': 170,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GXQA/PDBs_Clean/1GXQA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GXQA/PDBs_Clean/1GXQA.pdbA/Peeling/Peeling.log'},
#  {'id': 171,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GY7A/PDBs_Clean/1GY7A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GY7A/PDBs_Clean/1GY7A.pdbA/Peeling/Peeling.log'},
#  {'id': 172,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GYXA/PDBs_Clean/1GYXA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GYXA/PDBs_Clean/1GYXA.pdbA/Peeling/Peeling.log'},
#  {'id': 173,
#   'source': 'dataset',
#   'path': '../data/data_sword/1GZSB/PDBs_Clean/1GZSB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/1GZSB/PDBs_Clean/1GZSB.pdbB/Peeling/Peeling.log'},
#  {'id': 174,
#   'source': 'dataset',
#   'path': '../data/data_sword/1H2CA/PDBs_Clean/1H2CA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1H2CA/PDBs_Clean/1H2CA.pdbA/Peeling/Peeling.log'},
#  {'id': 175,
#   'source': 'dataset',
#   'path': '../data/data_sword/1H2EA/PDBs_Clean/1H2EA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1H2EA/PDBs_Clean/1H2EA.pdbA/Peeling/Peeling.log'},
#  {'id': 176,
#   'source': 'dataset',
#   'path': '../data/data_sword/1H3DA/PDBs_Clean/1H3DA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1H3DA/PDBs_Clean/1H3DA.pdbA/Peeling/Peeling.log'},
#  {'id': 177,
#   'source': 'dataset',
#   'path': '../data/data_sword/1H3LA/PDBs_Clean/1H3LA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1H3LA/PDBs_Clean/1H3LA.pdbA/Peeling/Peeling.log'},
#  {'id': 178,
#   'source': 'dataset',
#   'path': '../data/data_sword/1H4XA/PDBs_Clean/1H4XA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1H4XA/PDBs_Clean/1H4XA.pdbA/Peeling/Peeling.log'},
#  {'id': 179,
#   'source': 'dataset',
#   'path': '../data/data_sword/1H54A/PDBs_Clean/1H54A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1H54A/PDBs_Clean/1H54A.pdbA/Peeling/Peeling.log'},
#  {'id': 180,
#   'source': 'dataset',
#   'path': '../data/data_sword/1H5WA/PDBs_Clean/1H5WA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1H5WA/PDBs_Clean/1H5WA.pdbA/Peeling/Peeling.log'},
#  {'id': 181,
#   'source': 'dataset',
#   'path': '../data/data_sword/1H6HA/PDBs_Clean/1H6HA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1H6HA/PDBs_Clean/1H6HA.pdbA/Peeling/Peeling.log'},
#  {'id': 182,
#   'source': 'dataset',
#   'path': '../data/data_sword/1H6KX/PDBs_Clean/1H6KX.pdbX/file_proba_contact.mat',
#   'annot': '../data/data_sword/1H6KX/PDBs_Clean/1H6KX.pdbX/Peeling/Peeling.log'},
#  {'id': 183,
#   'source': 'dataset',
#   'path': '../data/data_sword/1H72C/PDBs_Clean/1H72C.pdbC/file_proba_contact.mat',
#   'annot': '../data/data_sword/1H72C/PDBs_Clean/1H72C.pdbC/Peeling/Peeling.log'},
#  {'id': 184,
#   'source': 'dataset',
#   'path': '../data/data_sword/1H7CA/PDBs_Clean/1H7CA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1H7CA/PDBs_Clean/1H7CA.pdbA/Peeling/Peeling.log'},
#  {'id': 185,
#   'source': 'dataset',
#   'path': '../data/data_sword/1H9DB/PDBs_Clean/1H9DB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/1H9DB/PDBs_Clean/1H9DB.pdbB/Peeling/Peeling.log'},
#  {'id': 186,
#   'source': 'dataset',
#   'path': '../data/data_sword/1H9OA/PDBs_Clean/1H9OA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1H9OA/PDBs_Clean/1H9OA.pdbA/Peeling/Peeling.log'},
#  {'id': 187,
#   'source': 'dataset',
#   'path': '../data/data_sword/1HBNC/PDBs_Clean/1HBNC.pdbC/file_proba_contact.mat',
#   'annot': '../data/data_sword/1HBNC/PDBs_Clean/1HBNC.pdbC/Peeling/Peeling.log'},
#  {'id': 188,
#   'source': 'dataset',
#   'path': '../data/data_sword/1HC7A/PDBs_Clean/1HC7A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1HC7A/PDBs_Clean/1HC7A.pdbA/Peeling/Peeling.log'},
#  {'id': 189,
#   'source': 'dataset',
#   'path': '../data/data_sword/1HCNB/PDBs_Clean/1HCNB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/1HCNB/PDBs_Clean/1HCNB.pdbB/Peeling/Peeling.log'},
#  {'id': 190,
#   'source': 'dataset',
#   'path': '../data/data_sword/1HD2A/PDBs_Clean/1HD2A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1HD2A/PDBs_Clean/1HD2A.pdbA/Peeling/Peeling.log'},
#  {'id': 191,
#   'source': 'dataset',
#   'path': '../data/data_sword/1HDKA/PDBs_Clean/1HDKA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1HDKA/PDBs_Clean/1HDKA.pdbA/Peeling/Peeling.log'},
#  {'id': 192,
#   'source': 'dataset',
#   'path': '../data/data_sword/1HEKA/PDBs_Clean/1HEKA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1HEKA/PDBs_Clean/1HEKA.pdbA/Peeling/Peeling.log'},
#  {'id': 193,
#   'source': 'dataset',
#   'path': '../data/data_sword/1HH1A/PDBs_Clean/1HH1A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1HH1A/PDBs_Clean/1HH1A.pdbA/Peeling/Peeling.log'},
#  {'id': 194,
#   'source': 'dataset',
#   'path': '../data/data_sword/1HLBA/PDBs_Clean/1HLBA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1HLBA/PDBs_Clean/1HLBA.pdbA/Peeling/Peeling.log'},
#  {'id': 195,
#   'source': 'dataset',
#   'path': '../data/data_sword/1HM9A/PDBs_Clean/1HM9A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1HM9A/PDBs_Clean/1HM9A.pdbA/Peeling/Peeling.log'},
#  {'id': 196,
#   'source': 'dataset',
#   'path': '../data/data_sword/1HRUA/PDBs_Clean/1HRUA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1HRUA/PDBs_Clean/1HRUA.pdbA/Peeling/Peeling.log'},
#  {'id': 197,
#   'source': 'dataset',
#   'path': '../data/data_sword/1HSSA/PDBs_Clean/1HSSA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1HSSA/PDBs_Clean/1HSSA.pdbA/Peeling/Peeling.log'},
#  {'id': 198,
#   'source': 'dataset',
#   'path': '../data/data_sword/1HULA/PDBs_Clean/1HULA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1HULA/PDBs_Clean/1HULA.pdbA/Peeling/Peeling.log'},
#  {'id': 199,
#   'source': 'dataset',
#   'path': '../data/data_sword/1HXIA/PDBs_Clean/1HXIA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1HXIA/PDBs_Clean/1HXIA.pdbA/Peeling/Peeling.log'},
#  {'id': 200,
#   'source': 'dataset',
#   'path': '../data/data_sword/1I1JA/PDBs_Clean/1I1JA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1I1JA/PDBs_Clean/1I1JA.pdbA/Peeling/Peeling.log'},
#  {'id': 201,
#   'source': 'dataset',
#   'path': '../data/data_sword/1I1NA/PDBs_Clean/1I1NA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1I1NA/PDBs_Clean/1I1NA.pdbA/Peeling/Peeling.log'},
#  {'id': 202,
#   'source': 'dataset',
#   'path': '../data/data_sword/1I1QA/PDBs_Clean/1I1QA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1I1QA/PDBs_Clean/1I1QA.pdbA/Peeling/Peeling.log'},
#  {'id': 203,
#   'source': 'dataset',
#   'path': '../data/data_sword/1I27A/PDBs_Clean/1I27A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1I27A/PDBs_Clean/1I27A.pdbA/Peeling/Peeling.log'},
#  {'id': 204,
#   'source': 'dataset',
#   'path': '../data/data_sword/1I4JA/PDBs_Clean/1I4JA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1I4JA/PDBs_Clean/1I4JA.pdbA/Peeling/Peeling.log'},
#  {'id': 205,
#   'source': 'dataset',
#   'path': '../data/data_sword/1I6AA/PDBs_Clean/1I6AA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1I6AA/PDBs_Clean/1I6AA.pdbA/Peeling/Peeling.log'},
#  {'id': 206,
#   'source': 'dataset',
#   'path': '../data/data_sword/1I6UA/PDBs_Clean/1I6UA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1I6UA/PDBs_Clean/1I6UA.pdbA/Peeling/Peeling.log'},
#  {'id': 207,
#   'source': 'dataset',
#   'path': '../data/data_sword/1I71A/PDBs_Clean/1I71A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1I71A/PDBs_Clean/1I71A.pdbA/Peeling/Peeling.log'},
#  {'id': 208,
#   'source': 'dataset',
#   'path': '../data/data_sword/1I7HA/PDBs_Clean/1I7HA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1I7HA/PDBs_Clean/1I7HA.pdbA/Peeling/Peeling.log'},
#  {'id': 209,
#   'source': 'dataset',
#   'path': '../data/data_sword/1I8AA/PDBs_Clean/1I8AA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1I8AA/PDBs_Clean/1I8AA.pdbA/Peeling/Peeling.log'},
#  {'id': 210,
#   'source': 'dataset',
#   'path': '../data/data_sword/1I8LA/PDBs_Clean/1I8LA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1I8LA/PDBs_Clean/1I8LA.pdbA/Peeling/Peeling.log'},
#  {'id': 211,
#   'source': 'dataset',
#   'path': '../data/data_sword/1IA9A/PDBs_Clean/1IA9A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1IA9A/PDBs_Clean/1IA9A.pdbA/Peeling/Peeling.log'},
#  {'id': 212,
#   'source': 'dataset',
#   'path': '../data/data_sword/1ICFI/PDBs_Clean/1ICFI.pdbI/file_proba_contact.mat',
#   'annot': '../data/data_sword/1ICFI/PDBs_Clean/1ICFI.pdbI/Peeling/Peeling.log'},
#  {'id': 213,
#   'source': 'dataset',
#   'path': '../data/data_sword/1ID0A/PDBs_Clean/1ID0A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1ID0A/PDBs_Clean/1ID0A.pdbA/Peeling/Peeling.log'},
#  {'id': 214,
#   'source': 'dataset',
#   'path': '../data/data_sword/1IG0A/PDBs_Clean/1IG0A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1IG0A/PDBs_Clean/1IG0A.pdbA/Peeling/Peeling.log'},
#  {'id': 215,
#   'source': 'dataset',
#   'path': '../data/data_sword/1II5A/PDBs_Clean/1II5A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1II5A/PDBs_Clean/1II5A.pdbA/Peeling/Peeling.log'},
#  {'id': 216,
#   'source': 'dataset',
#   'path': '../data/data_sword/1IIBA/PDBs_Clean/1IIBA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1IIBA/PDBs_Clean/1IIBA.pdbA/Peeling/Peeling.log'},
#  {'id': 217,
#   'source': 'dataset',
#   'path': '../data/data_sword/1IJYA/PDBs_Clean/1IJYA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1IJYA/PDBs_Clean/1IJYA.pdbA/Peeling/Peeling.log'},
#  {'id': 218,
#   'source': 'dataset',
#   'path': '../data/data_sword/1IN0A/PDBs_Clean/1IN0A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1IN0A/PDBs_Clean/1IN0A.pdbA/Peeling/Peeling.log'},
#  {'id': 219,
#   'source': 'dataset',
#   'path': '../data/data_sword/1INLA/PDBs_Clean/1INLA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1INLA/PDBs_Clean/1INLA.pdbA/Peeling/Peeling.log'},
#  {'id': 220,
#   'source': 'dataset',
#   'path': '../data/data_sword/1IO1A/PDBs_Clean/1IO1A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1IO1A/PDBs_Clean/1IO1A.pdbA/Peeling/Peeling.log'},
#  {'id': 221,
#   'source': 'dataset',
#   'path': '../data/data_sword/1IQ4A/PDBs_Clean/1IQ4A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1IQ4A/PDBs_Clean/1IQ4A.pdbA/Peeling/Peeling.log'},
#  {'id': 222,
#   'source': 'dataset',
#   'path': '../data/data_sword/1ISUA/PDBs_Clean/1ISUA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1ISUA/PDBs_Clean/1ISUA.pdbA/Peeling/Peeling.log'},
#  {'id': 223,
#   'source': 'dataset',
#   'path': '../data/data_sword/1IT2A/PDBs_Clean/1IT2A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1IT2A/PDBs_Clean/1IT2A.pdbA/Peeling/Peeling.log'},
#  {'id': 224,
#   'source': 'dataset',
#   'path': '../data/data_sword/1IWMA/PDBs_Clean/1IWMA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1IWMA/PDBs_Clean/1IWMA.pdbA/Peeling/Peeling.log'},
#  {'id': 225,
#   'source': 'dataset',
#   'path': '../data/data_sword/1IZ5A/PDBs_Clean/1IZ5A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1IZ5A/PDBs_Clean/1IZ5A.pdbA/Peeling/Peeling.log'},
#  {'id': 226,
#   'source': 'dataset',
#   'path': '../data/data_sword/1J0PA/PDBs_Clean/1J0PA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1J0PA/PDBs_Clean/1J0PA.pdbA/Peeling/Peeling.log'},
#  {'id': 227,
#   'source': 'dataset',
#   'path': '../data/data_sword/1J34A/PDBs_Clean/1J34A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1J34A/PDBs_Clean/1J34A.pdbA/Peeling/Peeling.log'},
#  {'id': 228,
#   'source': 'dataset',
#   'path': '../data/data_sword/1J3EA/PDBs_Clean/1J3EA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1J3EA/PDBs_Clean/1J3EA.pdbA/Peeling/Peeling.log'},
#  {'id': 229,
#   'source': 'dataset',
#   'path': '../data/data_sword/1J3LA/PDBs_Clean/1J3LA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1J3LA/PDBs_Clean/1J3LA.pdbA/Peeling/Peeling.log'},
#  {'id': 230,
#   'source': 'dataset',
#   'path': '../data/data_sword/1J3MA/PDBs_Clean/1J3MA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1J3MA/PDBs_Clean/1J3MA.pdbA/Peeling/Peeling.log'},
#  {'id': 231,
#   'source': 'dataset',
#   'path': '../data/data_sword/1J48A/PDBs_Clean/1J48A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1J48A/PDBs_Clean/1J48A.pdbA/Peeling/Peeling.log'},
#  {'id': 232,
#   'source': 'dataset',
#   'path': '../data/data_sword/1J83A/PDBs_Clean/1J83A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1J83A/PDBs_Clean/1J83A.pdbA/Peeling/Peeling.log'},
#  {'id': 233,
#   'source': 'dataset',
#   'path': '../data/data_sword/1J93A/PDBs_Clean/1J93A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1J93A/PDBs_Clean/1J93A.pdbA/Peeling/Peeling.log'},
#  {'id': 234,
#   'source': 'dataset',
#   'path': '../data/data_sword/1J98A/PDBs_Clean/1J98A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1J98A/PDBs_Clean/1J98A.pdbA/Peeling/Peeling.log'},
#  {'id': 235,
#   'source': 'dataset',
#   'path': '../data/data_sword/1JATB/PDBs_Clean/1JATB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/1JATB/PDBs_Clean/1JATB.pdbB/Peeling/Peeling.log'},
#  {'id': 236,
#   'source': 'dataset',
#   'path': '../data/data_sword/1JB0A/PDBs_Clean/1JB0A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/1JB0A/PDBs_Clean/1JB0A.pdbA/Peeling/Peeling.log'},
#  {'id': 237,
#   'source': 'dataset',
#   'path': '../data/data_sword/1JB0D/PDBs_Clean/1JB0D.pdbD/file_proba_contact.mat',
#   'annot': '../data/data_sword/1JB0D/PDBs_Clean/1JB0D.pdbD/Peeling/Peeling.log'},
#  {'id': 238,
#   'source': 'dataset',
#   'path': '../data/data_sword/1JB0E/PDBs_Clean/1JB0E.pdbE/file_proba_contact.mat',
#   'annot': '../data/data_sword/1JB0E/PDBs_Clean/1JB0E.pdbE/Peeling/Peeling.log'},
#  {'id': 239,
#   'source': 'dataset',
# ...
#   'annot': '../data/data_sword/2A1VA/PDBs_Clean/2A1VA.pdbA/Peeling/Peeling.log'},
#  {'id': 921,
#   'source': 'dataset',
#   'path': '../data/data_sword/2A25A/PDBs_Clean/2A25A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2A25A/PDBs_Clean/2A25A.pdbA/Peeling/Peeling.log'},
#  {'id': 922,
#   'source': 'dataset',
#   'path': '../data/data_sword/2A2LA/PDBs_Clean/2A2LA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2A2LA/PDBs_Clean/2A2LA.pdbA/Peeling/Peeling.log'},
#  {'id': 923,
#   'source': 'dataset',
#   'path': '../data/data_sword/2A3VA/PDBs_Clean/2A3VA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2A3VA/PDBs_Clean/2A3VA.pdbA/Peeling/Peeling.log'},
#  {'id': 924,
#   'source': 'dataset',
#   'path': '../data/data_sword/2A4VA/PDBs_Clean/2A4VA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2A4VA/PDBs_Clean/2A4VA.pdbA/Peeling/Peeling.log'},
#  {'id': 925,
#   'source': 'dataset',
#   'path': '../data/data_sword/2A5ZA/PDBs_Clean/2A5ZA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2A5ZA/PDBs_Clean/2A5ZA.pdbA/Peeling/Peeling.log'},
#  {'id': 926,
#   'source': 'dataset',
#   'path': '../data/data_sword/2A6HE/PDBs_Clean/2A6HE.pdbE/file_proba_contact.mat',
#   'annot': '../data/data_sword/2A6HE/PDBs_Clean/2A6HE.pdbE/Peeling/Peeling.log'},
#  {'id': 927,
#   'source': 'dataset',
#   'path': '../data/data_sword/2A90A/PDBs_Clean/2A90A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2A90A/PDBs_Clean/2A90A.pdbA/Peeling/Peeling.log'},
#  {'id': 928,
#   'source': 'dataset',
#   'path': '../data/data_sword/2AAMA/PDBs_Clean/2AAMA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2AAMA/PDBs_Clean/2AAMA.pdbA/Peeling/Peeling.log'},
#  {'id': 929,
#   'source': 'dataset',
#   'path': '../data/data_sword/2ABWA/PDBs_Clean/2ABWA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2ABWA/PDBs_Clean/2ABWA.pdbA/Peeling/Peeling.log'},
#  {'id': 930,
#   'source': 'dataset',
#   'path': '../data/data_sword/2AC3A/PDBs_Clean/2AC3A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2AC3A/PDBs_Clean/2AC3A.pdbA/Peeling/Peeling.log'},
#  {'id': 931,
#   'source': 'dataset',
#   'path': '../data/data_sword/2ACFA/PDBs_Clean/2ACFA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2ACFA/PDBs_Clean/2ACFA.pdbA/Peeling/Peeling.log'},
#  {'id': 932,
#   'source': 'dataset',
#   'path': '../data/data_sword/2AE6A/PDBs_Clean/2AE6A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2AE6A/PDBs_Clean/2AE6A.pdbA/Peeling/Peeling.log'},
#  {'id': 933,
#   'source': 'dataset',
#   'path': '../data/data_sword/2AEGA/PDBs_Clean/2AEGA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2AEGA/PDBs_Clean/2AEGA.pdbA/Peeling/Peeling.log'},
#  {'id': 934,
#   'source': 'dataset',
#   'path': '../data/data_sword/2AF7A/PDBs_Clean/2AF7A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2AF7A/PDBs_Clean/2AF7A.pdbA/Peeling/Peeling.log'},
#  {'id': 935,
#   'source': 'dataset',
#   'path': '../data/data_sword/2AFBA/PDBs_Clean/2AFBA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2AFBA/PDBs_Clean/2AFBA.pdbA/Peeling/Peeling.log'},
#  {'id': 936,
#   'source': 'dataset',
#   'path': '../data/data_sword/2AHDA/PDBs_Clean/2AHDA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2AHDA/PDBs_Clean/2AHDA.pdbA/Peeling/Peeling.log'},
#  {'id': 937,
#   'source': 'dataset',
#   'path': '../data/data_sword/2AHMA/PDBs_Clean/2AHMA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2AHMA/PDBs_Clean/2AHMA.pdbA/Peeling/Peeling.log'},
#  {'id': 938,
#   'source': 'dataset',
#   'path': '../data/data_sword/2AIBA/PDBs_Clean/2AIBA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2AIBA/PDBs_Clean/2AIBA.pdbA/Peeling/Peeling.log'},
#  {'id': 939,
#   'source': 'dataset',
#   'path': '../data/data_sword/2AJ6A/PDBs_Clean/2AJ6A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2AJ6A/PDBs_Clean/2AJ6A.pdbA/Peeling/Peeling.log'},
#  {'id': 940,
#   'source': 'dataset',
#   'path': '../data/data_sword/2ANEA/PDBs_Clean/2ANEA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2ANEA/PDBs_Clean/2ANEA.pdbA/Peeling/Peeling.log'},
#  {'id': 941,
#   'source': 'dataset',
#   'path': '../data/data_sword/2ANRA/PDBs_Clean/2ANRA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2ANRA/PDBs_Clean/2ANRA.pdbA/Peeling/Peeling.log'},
#  {'id': 942,
#   'source': 'dataset',
#   'path': '../data/data_sword/2AO9A/PDBs_Clean/2AO9A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2AO9A/PDBs_Clean/2AO9A.pdbA/Peeling/Peeling.log'},
#  {'id': 943,
#   'source': 'dataset',
#   'path': '../data/data_sword/2AOTA/PDBs_Clean/2AOTA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2AOTA/PDBs_Clean/2AOTA.pdbA/Peeling/Peeling.log'},
#  {'id': 944,
#   'source': 'dataset',
#   'path': '../data/data_sword/2APRA/PDBs_Clean/2APRA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2APRA/PDBs_Clean/2APRA.pdbA/Peeling/Peeling.log'},
#  {'id': 945,
#   'source': 'dataset',
#   'path': '../data/data_sword/2AQ5A/PDBs_Clean/2AQ5A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2AQ5A/PDBs_Clean/2AQ5A.pdbA/Peeling/Peeling.log'},
#  {'id': 946,
#   'source': 'dataset',
#   'path': '../data/data_sword/2ARRA/PDBs_Clean/2ARRA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2ARRA/PDBs_Clean/2ARRA.pdbA/Peeling/Peeling.log'},
#  {'id': 947,
#   'source': 'dataset',
#   'path': '../data/data_sword/2ARZA/PDBs_Clean/2ARZA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2ARZA/PDBs_Clean/2ARZA.pdbA/Peeling/Peeling.log'},
#  {'id': 948,
#   'source': 'dataset',
#   'path': '../data/data_sword/2ASFA/PDBs_Clean/2ASFA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2ASFA/PDBs_Clean/2ASFA.pdbA/Peeling/Peeling.log'},
#  {'id': 949,
#   'source': 'dataset',
#   'path': '../data/data_sword/2ATZA/PDBs_Clean/2ATZA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2ATZA/PDBs_Clean/2ATZA.pdbA/Peeling/Peeling.log'},
#  {'id': 950,
#   'source': 'dataset',
#   'path': '../data/data_sword/2AU5A/PDBs_Clean/2AU5A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2AU5A/PDBs_Clean/2AU5A.pdbA/Peeling/Peeling.log'},
#  {'id': 951,
#   'source': 'dataset',
#   'path': '../data/data_sword/2AUKA/PDBs_Clean/2AUKA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2AUKA/PDBs_Clean/2AUKA.pdbA/Peeling/Peeling.log'},
#  {'id': 952,
#   'source': 'dataset',
#   'path': '../data/data_sword/2AXYA/PDBs_Clean/2AXYA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2AXYA/PDBs_Clean/2AXYA.pdbA/Peeling/Peeling.log'},
#  {'id': 953,
#   'source': 'dataset',
#   'path': '../data/data_sword/2AYDA/PDBs_Clean/2AYDA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2AYDA/PDBs_Clean/2AYDA.pdbA/Peeling/Peeling.log'},
#  {'id': 954,
#   'source': 'dataset',
#   'path': '../data/data_sword/2AZ0A/PDBs_Clean/2AZ0A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2AZ0A/PDBs_Clean/2AZ0A.pdbA/Peeling/Peeling.log'},
#  {'id': 955,
#   'source': 'dataset',
#   'path': '../data/data_sword/2AZ4A/PDBs_Clean/2AZ4A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2AZ4A/PDBs_Clean/2AZ4A.pdbA/Peeling/Peeling.log'},
#  {'id': 956,
#   'source': 'dataset',
#   'path': '../data/data_sword/2AZEB/PDBs_Clean/2AZEB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/2AZEB/PDBs_Clean/2AZEB.pdbB/Peeling/Peeling.log'},
#  {'id': 957,
#   'source': 'dataset',
#   'path': '../data/data_sword/2B06A/PDBs_Clean/2B06A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2B06A/PDBs_Clean/2B06A.pdbA/Peeling/Peeling.log'},
#  {'id': 958,
#   'source': 'dataset',
#   'path': '../data/data_sword/2B0CA/PDBs_Clean/2B0CA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2B0CA/PDBs_Clean/2B0CA.pdbA/Peeling/Peeling.log'},
#  {'id': 959,
#   'source': 'dataset',
#   'path': '../data/data_sword/2B0OE/PDBs_Clean/2B0OE.pdbE/file_proba_contact.mat',
#   'annot': '../data/data_sword/2B0OE/PDBs_Clean/2B0OE.pdbE/Peeling/Peeling.log'},
#  {'id': 960,
#   'source': 'dataset',
#   'path': '../data/data_sword/2B0RA/PDBs_Clean/2B0RA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2B0RA/PDBs_Clean/2B0RA.pdbA/Peeling/Peeling.log'},
#  {'id': 961,
#   'source': 'dataset',
#   'path': '../data/data_sword/2B3GA/PDBs_Clean/2B3GA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2B3GA/PDBs_Clean/2B3GA.pdbA/Peeling/Peeling.log'},
#  {'id': 962,
#   'source': 'dataset',
#   'path': '../data/data_sword/2B3RA/PDBs_Clean/2B3RA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2B3RA/PDBs_Clean/2B3RA.pdbA/Peeling/Peeling.log'},
#  {'id': 963,
#   'source': 'dataset',
#   'path': '../data/data_sword/2B3ZA/PDBs_Clean/2B3ZA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2B3ZA/PDBs_Clean/2B3ZA.pdbA/Peeling/Peeling.log'},
#  {'id': 964,
#   'source': 'dataset',
#   'path': '../data/data_sword/2B4WA/PDBs_Clean/2B4WA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2B4WA/PDBs_Clean/2B4WA.pdbA/Peeling/Peeling.log'},
#  {'id': 965,
#   'source': 'dataset',
#   'path': '../data/data_sword/2B5AA/PDBs_Clean/2B5AA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2B5AA/PDBs_Clean/2B5AA.pdbA/Peeling/Peeling.log'},
#  {'id': 966,
#   'source': 'dataset',
#   'path': '../data/data_sword/2B5DX/PDBs_Clean/2B5DX.pdbX/file_proba_contact.mat',
#   'annot': '../data/data_sword/2B5DX/PDBs_Clean/2B5DX.pdbX/Peeling/Peeling.log'},
#  {'id': 967,
#   'source': 'dataset',
#   'path': '../data/data_sword/2B5IC/PDBs_Clean/2B5IC.pdbC/file_proba_contact.mat',
#   'annot': '../data/data_sword/2B5IC/PDBs_Clean/2B5IC.pdbC/Peeling/Peeling.log'},
#  {'id': 968,
#   'source': 'dataset',
#   'path': '../data/data_sword/2B5ID/PDBs_Clean/2B5ID.pdbD/file_proba_contact.mat',
#   'annot': '../data/data_sword/2B5ID/PDBs_Clean/2B5ID.pdbD/Peeling/Peeling.log'},
#  {'id': 969,
#   'source': 'dataset',
#   'path': '../data/data_sword/2B6CA/PDBs_Clean/2B6CA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2B6CA/PDBs_Clean/2B6CA.pdbA/Peeling/Peeling.log'},
#  {'id': 970,
#   'source': 'dataset',
#   'path': '../data/data_sword/2B82A/PDBs_Clean/2B82A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2B82A/PDBs_Clean/2B82A.pdbA/Peeling/Peeling.log'},
#  {'id': 971,
#   'source': 'dataset',
#   'path': '../data/data_sword/2B8IA/PDBs_Clean/2B8IA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2B8IA/PDBs_Clean/2B8IA.pdbA/Peeling/Peeling.log'},
#  {'id': 972,
#   'source': 'dataset',
#   'path': '../data/data_sword/2B97A/PDBs_Clean/2B97A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2B97A/PDBs_Clean/2B97A.pdbA/Peeling/Peeling.log'},
#  {'id': 973,
#   'source': 'dataset',
#   'path': '../data/data_sword/2B99A/PDBs_Clean/2B99A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2B99A/PDBs_Clean/2B99A.pdbA/Peeling/Peeling.log'},
#  {'id': 974,
#   'source': 'dataset',
#   'path': '../data/data_sword/2B9HA/PDBs_Clean/2B9HA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2B9HA/PDBs_Clean/2B9HA.pdbA/Peeling/Peeling.log'},
#  {'id': 975,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BA0A/PDBs_Clean/2BA0A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BA0A/PDBs_Clean/2BA0A.pdbA/Peeling/Peeling.log'},
#  {'id': 976,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BA2A/PDBs_Clean/2BA2A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BA2A/PDBs_Clean/2BA2A.pdbA/Peeling/Peeling.log'},
#  {'id': 977,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BC4B/PDBs_Clean/2BC4B.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BC4B/PDBs_Clean/2BC4B.pdbB/Peeling/Peeling.log'},
#  {'id': 978,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BE3A/PDBs_Clean/2BE3A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BE3A/PDBs_Clean/2BE3A.pdbA/Peeling/Peeling.log'},
#  {'id': 979,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BFDA/PDBs_Clean/2BFDA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BFDA/PDBs_Clean/2BFDA.pdbA/Peeling/Peeling.log'},
#  {'id': 980,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BFWA/PDBs_Clean/2BFWA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BFWA/PDBs_Clean/2BFWA.pdbA/Peeling/Peeling.log'},
#  {'id': 981,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BGKA/PDBs_Clean/2BGKA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BGKA/PDBs_Clean/2BGKA.pdbA/Peeling/Peeling.log'},
#  {'id': 982,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BH9A/PDBs_Clean/2BH9A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BH9A/PDBs_Clean/2BH9A.pdbA/Peeling/Peeling.log'},
#  {'id': 983,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BHGA/PDBs_Clean/2BHGA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BHGA/PDBs_Clean/2BHGA.pdbA/Peeling/Peeling.log'},
#  {'id': 984,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BIIA/PDBs_Clean/2BIIA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BIIA/PDBs_Clean/2BIIA.pdbA/Peeling/Peeling.log'},
#  {'id': 985,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BJDA/PDBs_Clean/2BJDA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BJDA/PDBs_Clean/2BJDA.pdbA/Peeling/Peeling.log'},
#  {'id': 986,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BKFA/PDBs_Clean/2BKFA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BKFA/PDBs_Clean/2BKFA.pdbA/Peeling/Peeling.log'},
#  {'id': 987,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BKYX/PDBs_Clean/2BKYX.pdbX/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BKYX/PDBs_Clean/2BKYX.pdbX/Peeling/Peeling.log'},
#  {'id': 988,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BL9A/PDBs_Clean/2BL9A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BL9A/PDBs_Clean/2BL9A.pdbA/Peeling/Peeling.log'},
#  {'id': 989,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BLFB/PDBs_Clean/2BLFB.pdbB/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BLFB/PDBs_Clean/2BLFB.pdbB/Peeling/Peeling.log'},
#  {'id': 990,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BNMA/PDBs_Clean/2BNMA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BNMA/PDBs_Clean/2BNMA.pdbA/Peeling/Peeling.log'},
#  {'id': 991,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BOLA/PDBs_Clean/2BOLA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BOLA/PDBs_Clean/2BOLA.pdbA/Peeling/Peeling.log'},
#  {'id': 992,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BOPA/PDBs_Clean/2BOPA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BOPA/PDBs_Clean/2BOPA.pdbA/Peeling/Peeling.log'},
#  {'id': 993,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BPTA/PDBs_Clean/2BPTA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BPTA/PDBs_Clean/2BPTA.pdbA/Peeling/Peeling.log'},
#  {'id': 994,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BQ4A/PDBs_Clean/2BQ4A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BQ4A/PDBs_Clean/2BQ4A.pdbA/Peeling/Peeling.log'},
#  {'id': 995,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BRFA/PDBs_Clean/2BRFA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BRFA/PDBs_Clean/2BRFA.pdbA/Peeling/Peeling.log'},
#  {'id': 996,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BRJA/PDBs_Clean/2BRJA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BRJA/PDBs_Clean/2BRJA.pdbA/Peeling/Peeling.log'},
#  {'id': 997,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BT9A/PDBs_Clean/2BT9A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BT9A/PDBs_Clean/2BT9A.pdbA/Peeling/Peeling.log'},
#  {'id': 998,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BTLA/PDBs_Clean/2BTLA.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BTLA/PDBs_Clean/2BTLA.pdbA/Peeling/Peeling.log'},
#  {'id': 999,
#   'source': 'dataset',
#   'path': '../data/data_sword/2BU3A/PDBs_Clean/2BU3A.pdbA/file_proba_contact.mat',
#   'annot': '../data/data_sword/2BU3A/PDBs_Clean/2BU3A.pdbA/Peeling/Peeling.log'},
#  ...]

# %%
m,_ = train_set.load_mask(2)

# %%
train_set.image_ids
# Out:
# array([   0,    1,    2, ..., 3536, 3537, 3538])

# %%
train_set.load_image(2).shape
# Out:
# (256, 256, 3)

# %%
plt.imshow(train_set.load_image(2))

# %%
# plt.imshow(train_set.load_image(2))
# for i in range(4):
#     plt.imshow(m[:,:,i], cmap="gray",alpha = 0.3)

# %%
config = PUConfig()

# %%
# model = MaskRCNN(mode='training', model_dir='../results/', config = config )
# # load weights (mscoco) and exclude the output layers
# model.load_weights('/home/ragou/repo/github/mask/Mask_RCNN/mask_rcnn_coco.h5', by_name=True, exclude=["mrcnn_class_logits", "mrcnn_bbox_fc",  "mrcnn_bbox", "mrcnn_mask"])
# # train weights (output layers or 'heads')
# model.train(train_set, test_set, learning_rate=0.001, epochs=5, layers='heads')

# %% [markdown]
# # PREDICTIONS

# %% [markdown]
# 10 epoch :
#
# 131/131 [==============================] - 93s 713ms/step - batch: 65.0000 - size: 1.0000 - loss: 1.6026 - rpn_class_loss: 0.0773 - rpn_bbox_loss: 0.5268 - mrcnn_class_loss: 0.2491 - mrcnn_bbox_loss: 0.3700 - mrcnn_mask_loss: 0.3795 - val_loss: 1.7908 - val_rpn_class_loss: 0.1071 - val_rpn_bbox_loss: 0.6950 - val_mrcnn_class_loss: 0.2211 - val_mrcnn_bbox_loss: 0.3794 - val_mrcnn_mask_loss: 0.3883

# %%
import sys
mrcnnpath = "/home/ragou/repo/github/mask/Mask_RCNN"
sys.path.append(mrcnnpath)

# %%
# detect kangaroos in photos with mask rcnn model
from os import listdir
from xml.etree import ElementTree
from numpy import zeros
from numpy import asarray
from numpy import expand_dims
from matplotlib import pyplot as plt
from matplotlib.patches import Rectangle
from mrcnn.config import Config
from mrcnn.model import MaskRCNN
from mrcnn.model import mold_image
from mrcnn.utils import Dataset


from numpy import zeros
from numpy import asarray
from numpy import expand_dims
from numpy import mean
from mrcnn.config import Config
from mrcnn.model import MaskRCNN
from mrcnn.utils import Dataset
from mrcnn.utils import compute_ap
from mrcnn.model import load_image_gt
from mrcnn.model import mold_image, unmold_image
from mrcnn import utils
from mrcnn import visualize
from mrcnn.visualize import display_images
import mrcnn.model as modellib
from mrcnn.model import log

# %% [markdown]
# # Load Model

# %%
# !chmod 775 ../results/ -R
model = MaskRCNN(mode='inference', model_dir='../results/', config = config )
# load weights (mscoco) and exclude the output layers
# model.load_weights("../results/sword_pu_cfg20211118T1237/mask_rcnn_sword_pu_cfg_0001.h5", by_name=True)
# train weights (output layers or 'heads')
# model.train(train_set, test_set, learning_rate=0.001, epochs=5, layers='heads')

# %% [markdown]
# # Load Weights

# %%
# !chmod 775 ../results/ -R
model.load_weights("../results/sword_pu_80_cfg20211119T1706/mask_rcnn_sword_pu_80_cfg_0063.h5", by_name=True)
# Out:
# Re-starting from epoch 67

# %% [markdown]
# pu_cfg20211117T1133 --> pas mal
#
# sword_pu_cfg20211117T2323 --> OK epoch 7
#
# 131/131 [==============================] - 90s 684ms/step - batch: 65.0000 - size: 1.0000 - loss: 1.6956 - rpn_class_loss: 0.1498 - rpn_bbox_loss: 0.6162 - mrcnn_class_loss: 0.2013 - mrcnn_bbox_loss: 0.3790 - mrcnn_mask_loss: 0.3493 - val_loss: 1.3416 - val_rpn_class_loss: 0.1143 - val_rpn_bbox_loss: 0.3344 - val_mrcnn_class_loss: 0.2010 - val_mrcnn_bbox_loss: 0.3535 - val_mrcnn_mask_loss: 0.3384
#
#
# sword_pu_full512_cfg20211118T1654 --> epoch 2 pas mal
#
#
# Selon les plots : sword_pu_cfg20211118T1328 epoch 8 : effectivement
#
# sword_pu_cfg20211118T1328

# %%
def get_ax(rows=1, cols=1, size=16):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Adjust the size attribute to control how big to render images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))

    return ax

# %%
def plot_results(dataset, num_image = -1, n_row = 2, n_col = 2):
    plt.figure(figsize=(10,10))
    ax = get_ax(n_row,n_col)
    for i in range(n_row):
        for j in range(n_col):
            if n_row == n_col == 1:
                axis = ax
            elif (n_row == 1 and n_col > 1) or (n_col == 1 and n_row > 1):
                axis = ax[j]
            else:
                axis = ax[i,j]
            if num_image == -1:
                image_id = random.choice(dataset.image_ids)

            else:
                image_id = num_image
            image, image_meta, gt_class_id, gt_bbox, gt_mask =\
                load_image_gt(test_set, config, image_id)
            info = test_set.image_info[image_id]
            print("image ID: {}.{} ({}) {}".format(info["source"], info["id"], image_id, 
                                                   test_set.image_reference(image_id)))
            # Run object detection
            results = model.detect([image], verbose=1)

            # Display results

            r = results[0]

            lab = test_set.get_PU(image_id)

            for i_box in range(len(lab)):
                # get coordinates
                x1, y1 = lab[i_box]
                # calculate width and height of the box
                size = y1 - x1
                # create the shape
                rect = Rectangle((x1, x1), size, size, fill=False, color='white', lw = 7)
                # draw the box
                axis.add_patch(rect)
            visualize.display_instances(image, r['rois'], r['masks'], r['class_ids'], 
                                        test_set.class_names, r['scores'], ax=axis,
                                        title=f"Predictions for id {image_id}")
            log("gt_class_id", gt_class_id)
            log("gt_bbox", gt_bbox)
            log("gt_mask", gt_mask)
            # plt.imshow(image)

# %%
plot_results(test_set,num_image = -1, n_row = 3, n_col = 3)
# Out:
# image ID: dataset.2755 (2755) ../data/data_sword/3M1RA/PDBs_Clean/3M1RA.pdbA/file_proba_contact.mat
# Processing 1 images
# image                    shape: (256, 256, 3)         min:    0.00000  max:  247.00000  uint8
# molded_images            shape: (1, 256, 256, 3)      min: -123.70000  max:  143.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  256.00000  int64
# anchors                  shape: (1, 16368, 4)         min:   -1.41976  max:    2.16878  float32
# gt_class_id              shape: (8,)                  min:    1.00000  max:    1.00000  int32
# gt_bbox                  shape: (8, 4)                min:    0.00000  max:  256.00000  int32
# gt_mask                  shape: (16, 16, 8)           min:    1.00000  max:    1.00000  bool
# image ID: dataset.1788 (1788) ../data/data_sword/2X4HA/PDBs_Clean/2X4HA.pdbA/file_proba_contact.mat
# Processing 1 images
# image                    shape: (256, 256, 3)         min:    0.00000  max:  249.00000  uint8
# molded_images            shape: (1, 256, 256, 3)      min: -123.70000  max:  145.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  256.00000  int64
# anchors                  shape: (1, 16368, 4)         min:   -1.41976  max:    2.16878  float32
# gt_class_id              shape: (4,)                  min:    1.00000  max:    1.00000  int32
# gt_bbox                  shape: (4, 4)                min:    1.00000  max:  256.00000  int32
# gt_mask                  shape: (16, 16, 4)           min:    1.00000  max:    1.00000  bool
# image ID: dataset.2576 (2576) ../data/data_sword/3ISYA/PDBs_Clean/3ISYA.pdbA/file_proba_contact.mat
# Processing 1 images
# image                    shape: (256, 256, 3)         min:    0.00000  max:  249.00000  uint8
# molded_images            shape: (1, 256, 256, 3)      min: -123.70000  max:  145.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  256.00000  int64
# anchors                  shape: (1, 16368, 4)         min:   -1.41976  max:    2.16878  float32
# gt_class_id              shape: (3,)                  min:    1.00000  max:    1.00000  int32
# gt_bbox                  shape: (3, 4)                min:    2.00000  max:  256.00000  int32
# gt_mask                  shape: (16, 16, 3)           min:    1.00000  max:    1.00000  bool
# image ID: dataset.1425 (1425) ../data/data_sword/2OBPA/PDBs_Clean/2OBPA.pdbA/file_proba_contact.mat
# Processing 1 images
# image                    shape: (256, 256, 3)         min:    0.00000  max:  249.00000  uint8
# molded_images            shape: (1, 256, 256, 3)      min: -123.70000  max:  145.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  256.00000  int64
# anchors                  shape: (1, 16368, 4)         min:   -1.41976  max:    2.16878  float32
# gt_class_id              shape: (2,)                  min:    1.00000  max:    1.00000  int32
# gt_bbox                  shape: (2, 4)                min:    3.00000  max:  256.00000  int32
# gt_mask                  shape: (16, 16, 2)           min:    1.00000  max:    1.00000  bool
# image ID: dataset.954 (954) ../data/data_sword/2AZ0A/PDBs_Clean/2AZ0A.pdbA/file_proba_contact.mat
# Processing 1 images
# image                    shape: (256, 256, 3)         min:    0.00000  max:  249.00000  uint8
# molded_images            shape: (1, 256, 256, 3)      min: -123.70000  max:  145.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  256.00000  int64
# anchors                  shape: (1, 16368, 4)         min:   -1.41976  max:    2.16878  float32
# gt_class_id              shape: (2,)                  min:    1.00000  max:    1.00000  int32
# gt_bbox                  shape: (2, 4)                min:    3.00000  max:  256.00000  int32
# gt_mask                  shape: (16, 16, 2)           min:    1.00000  max:    1.00000  bool
# image ID: dataset.1250 (1250) ../data/data_sword/2HBJA/PDBs_Clean/2HBJA.pdbA/file_proba_contact.mat
# Processing 1 images
# image                    shape: (256, 256, 3)         min:    0.00000  max:  249.00000  uint8
# molded_images            shape: (1, 256, 256, 3)      min: -123.70000  max:  145.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  256.00000  int64
# anchors                  shape: (1, 16368, 4)         min:   -1.41976  max:    2.16878  float32
# gt_class_id              shape: (10,)                 min:    1.00000  max:    1.00000  int32
# gt_bbox                  shape: (10, 4)               min:    0.00000  max:  256.00000  int32
# gt_mask                  shape: (16, 16, 10)          min:    1.00000  max:    1.00000  bool
# image ID: dataset.136 (136) ../data/data_sword/1FO0B/PDBs_Clean/1FO0B.pdbB/file_proba_contact.mat
# Processing 1 images
# image                    shape: (256, 256, 3)         min:    0.00000  max:  247.00000  uint8
# molded_images            shape: (1, 256, 256, 3)      min: -123.70000  max:  143.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  256.00000  int64
# anchors                  shape: (1, 16368, 4)         min:   -1.41976  max:    2.16878  float32
# gt_class_id              shape: (3,)                  min:    1.00000  max:    1.00000  int32
# gt_bbox                  shape: (3, 4)                min:    2.00000  max:  256.00000  int32
# gt_mask                  shape: (16, 16, 3)           min:    1.00000  max:    1.00000  bool
# image ID: dataset.1361 (1361) ../data/data_sword/2JBHA/PDBs_Clean/2JBHA.pdbA/file_proba_contact.mat
# Processing 1 images
# image                    shape: (256, 256, 3)         min:    0.00000  max:  247.00000  uint8
# molded_images            shape: (1, 256, 256, 3)      min: -123.70000  max:  143.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  256.00000  int64
# anchors                  shape: (1, 16368, 4)         min:   -1.41976  max:    2.16878  float32
# gt_class_id              shape: (6,)                  min:    1.00000  max:    1.00000  int32
# gt_bbox                  shape: (6, 4)                min:    1.00000  max:  256.00000  int32
# gt_mask                  shape: (16, 16, 6)           min:    1.00000  max:    1.00000  bool
# image ID: dataset.2902 (2902) ../data/data_sword/3O0GD/PDBs_Clean/3O0GD.pdbD/file_proba_contact.mat
# Processing 1 images
# image                    shape: (256, 256, 3)         min:    0.00000  max:  247.00000  uint8
# molded_images            shape: (1, 256, 256, 3)      min: -123.70000  max:  143.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  256.00000  int64
# anchors                  shape: (1, 16368, 4)         min:   -1.41976  max:    2.16878  float32
# gt_class_id              shape: (4,)                  min:    1.00000  max:    1.00000  int32
# gt_bbox                  shape: (4, 4)                min:    1.00000  max:  256.00000  int32
# gt_mask                  shape: (16, 16, 4)           min:    1.00000  max:    1.00000  bool

# %%
# calculate the mAP for a model on a given dataset
def evaluate_model(dataset, model, cfg):
    APs = list()
    for image_id in dataset.image_ids:
        # load image, bounding boxes and masks for the image id
        image, image_meta, gt_class_id, gt_bbox, gt_mask = load_image_gt(dataset, cfg, image_id)
        # convert pixel values (e.g. center)
        scaled_image = mold_image(image, cfg)
        # convert image into one sample
        sample = expand_dims(scaled_image, 0)
        
        # make prediction
        yhat = model.detect(sample, verbose=0)
        # extract results for first sample
        r = yhat[0]
        # calculate statistics, including AP
        AP, _, _, _ = compute_ap(gt_bbox, gt_class_id, gt_mask, r["rois"], r["class_ids"], r["scores"], r['masks'])
        print(AP)
        # store
        APs.append(AP)
    # calculate the mean AP across all images
    mAP = mean(APs)
    return mAP

# %%
# # Draw precision-recall curve
# AP, precisions, recalls, overlaps = utils.compute_ap(gt_bbox, gt_class_id, gt_mask,
#                                           r['rois'], r['class_ids'], r['scores'], r['masks'])
# visualize.plot_precision_recall(AP, precisions, recalls)

# %%
# !pip3 install scikit-image==0.16.2

# %%
# # evaluate model on training dataset
# train_mAP = evaluate_model(train_set, model, config)
# print("Train mAP: %.3f" % train_mAP)
# # evaluate model on test dataset
# test_mAP = evaluate_model(test_set, model, config)
# print("Test mAP: %.3f" % test_mAP)

# %%
# plot a number of photos with ground truth and predictions
def plot_actual_vs_predicted(dataset, model, cfg, n_images=1):
    plt.figure(figsize=(20,18))
    # load image and mask
    for i in range(n_images):
    
        # load the image and mask
        image = dataset.load_image(4)
        mask, _ = dataset.load_mask(4)
        lab = dataset.get_PU(4)
        # convert pixel values (e.g. center)
        scaled_image = mold_image(image, cfg)
        # convert image into one sample
        sample = expand_dims(scaled_image, 0)
        # make prediction
        yhat = model.detect([image], verbose=0)[0]
        # define subplot
        pyplot.subplot(n_images, 2, i*2+1)
        # plot raw pixel data
        pyplot.imshow(image)
        pyplot.title(f'Actual id :{4}')
        ax = pyplot.gca()
        # plot each box
        for i_box in range(len(lab)):
            # get coordinates
            x1, y1 = lab[i_box]
            # calculate width and height of the box
            size = y1 - x1
            # create the shape
            rect = Rectangle((x1, x1), size, size, fill=False, color='green')
            # draw the box
            ax.add_patch(rect)
#         # show the figure
#         pyplot.show()
        # get the context for drawing boxes
        pyplot.subplot(n_images, 2, i*2+2)
        # plot raw pixel data
        pyplot.imshow(image)
        pyplot.title('Predicted')
        ax = pyplot.gca()
        print(np.mean(yhat["scores"]))
        # plot each box
        for i_box in range(len(yhat['rois'])):
            # get coordinates
            y1, x1, y2, x2 = yhat['rois'][i_box]
            # calculate width and height of the box
            width, height = x2 - x1, y2 - y1
            # create the shape
            if yhat['scores'][i_box] > 0.71:
                
                rect = Rectangle((x1, y1), width, height, fill=False, color='red')
                # draw the box
                ax.add_patch(rect)
    # show the figure
    pyplot.show()

# %%
plot_actual_vs_predicted(test_set, model, config)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-a5011cdce05c> in <module>
# ----> 1 plot_actual_vs_predicted(test_set, model, config)
#
# <ipython-input-33-50801d1486cf> in plot_actual_vs_predicted(dataset, model, cfg, n_images)
#      16         yhat = model.detect([image], verbose=0)[0]
#      17         # define subplot
# ---> 18         pyplot.subplot(n_images, 2, i*2+1)
#      19         # plot raw pixel data
#      20         pyplot.imshow(image)
#
# NameError: name 'pyplot' is not defined
